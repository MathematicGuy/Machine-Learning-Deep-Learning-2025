# %% [markdown]
# ## EDA
# Understand Data Distribution and Structure so we could ultilize them for FE

# %%
import pandas as pd
import matplotlib as plt

df = pd.read_csv('../online_retail_II.csv')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
print("INFO")
print(df.info())
print()
print('DESCRIBE \n', df.describe())
print()
print('CHECK NULL \n', df.isnull().sum())
print()
print('CHECK DUPLICATE \n', df.duplicated().sum())
# Out:
# INFO
# <class 'pandas.core.frame.DataFrame'>
# Index: 1047877 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1047877 non-null  object
#  1   StockCode    1047877 non-null  object
#  2   Description  1043495 non-null  object
#  3   Quantity     1047877 non-null  int64
#  4   InvoiceDate  1047877 non-null  object
#  5   Price        1047877 non-null  float64
#  6   Customer ID  1047877 non-null  object
#  7   Country      1047877 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 72.0+ MB
# None
#
# DESCRIBE
#             Quantity         Price
# count  1.047877e+06  1.047877e+06
# mean   1.059235e+01  3.901109e+00
# std    1.352806e+02  9.435774e+01
# min   -9.600000e+03 -5.359436e+04
# 25%    1.000000e+00  1.250000e+00
# 50%    3.000000e+00  2.100000e+00
# 75%    1.000000e+01  4.130000e+00
# max    8.099500e+04  2.511109e+04
#
# CHECK NULL
# ...

# %% [markdown]
# ## Data Cleansing / Preprocessing
# Box-Cox
# Standard Scaler
# PCA

# %%
df["Customer ID"] = df["Customer ID"].astype("str").replace(".0", " ", regex=False).str.zfill(6)
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price Customer ID         Country
# ...

# %% [markdown]
# ### Clean Data

# %%
df = df[~df['Invoice'].astype('str').str.startswith("C")]
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price Customer ID         Country
# ...

# %% [markdown]
# ## Feature Engineer base on Customer Behaviour
# Testing +
# Validation
