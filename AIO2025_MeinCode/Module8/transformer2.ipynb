# %%
import torch
import numpy as np
from typing import List, Dict

# %%
class SimpleTokenizer:
    """
    A word-level tokenizer with special tokens.
    """

    def __init__(self):
        self.word_to_id: Dict[str, int] = {}
        self.id_to_word: Dict[int, str] = {}
        self.vocab_size = 0

        # Special tokens
        self.pad_token = "<PAD>"
        self.unk_token = "<UNK>"
        self.bos_token = "<BOS>"
        self.eos_token = "<EOS>"

    def build_vocab(self, texts: List[str]) -> None:
        """
        Build vocabulary from a list of texts.
        Add special tokens first, then unique words.
        """
        # YOUR CODE HERE
        vocab = set()
        special_token = [self.pad_token, self.unk_token, self.bos_token, self.eos_token]
        # add special token to vocab first
        # vocab = [token for token in special_token]
        vocab.update(special_token)
        vocab.add(texts.split()) # type: ignore
        print(vocab)


    def encode(self, text: str) -> List[int]:
        """
        Convert text to list of token IDs.
        Use UNK for unknown words.
        """
        # YOUR CODE HERE
        pass

    def decode(self, ids: List[int]) -> str:
        """
        Convert list of token IDs back to text.
        """
        # YOUR CODE HERE
        pass


Input = "hello world"
tokenizer = SimpleTokenizer()
print(tokenizer.build_vocab(Input)) # type: ignore
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 50
#      48 Input = "hello world"
#      49 tokenizer = SimpleTokenizer()
# ---> 50 print(tokenizer.build_vocab(Input)) # type: ignore
#
# Cell In[9], line 28, in SimpleTokenizer.build_vocab(self, texts)
#      25 # add special token to vocab first
#      26 # vocab = [token for token in special_token]
#      27 vocab.update(special_token)
# ---> 28 vocab.add([text for text in texts.split()]) # type: ignore
#      29 print(vocab)
#
# TypeError: unhashable type: 'list'

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
