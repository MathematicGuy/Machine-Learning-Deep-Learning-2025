# %% [markdown]
# ### Dependency
# Note:
# + **FFmpeg is a tool for encode and decode video and autio data into Pytorch tensor** -> Super Fast, Memory Efficiency compare to process video to raw frames (use raw frames only for visualization purpose).
# + Torchcodec is just FFmpeg but lighter and specialize for Pytorch.
#
# Setup TorchCodec:
# 1. Install FFmpeg to "Windows env" for torchcodec (gyan.dev version): `winget install "FFmpeg (Essentials Build)"`
# 2. Install "ffmpeg" to "Anaconda env" `conda install -c conda-forge "torchcodec=*=*cuda*"`
# 3. test `ffmpeg -hwaccel cuda -hwaccel_output_format cuda -i kicking.mp4 -f null -`

# %%
print("hallo")
# Out:
# hallo

# %%
import torch

print(f"{torch.__version__=}")
print(f"{torch.cuda.is_available()=}")
print(f"{torch.cuda.get_device_properties(0)=}")
# Out:
# torch.__version__='2.9.1+cu128'
# torch.cuda.is_available()=True
# torch.cuda.get_device_properties(0)=_CudaDeviceProperties(name='NVIDIA GeForce GTX 1650', major=7, minor=5, total_memory=4095MB, multi_processor_count=14, uuid=9626fe09-ad7e-3b01-0b7d-a2ed49b0eb94, pci_bus_id=1, pci_device_id=0, pci_domain_id=0, L2_cache_size=1MB)

# %%
# Use Python's Windows DLL API (3.8+). Add the folder that holds avcodec/avformat/avutil DLLs.
# TorchCodec README + version matrix: https://github.com/pytorch/torchcodec  (docs)

# from pathlib import Path
# import os, sys
# # Point this to the 'bin' folder of your 'asr' environment
# os.add_dll_directory(r"D:\Utilities\miniconda\envs\asr\Library\bin")

import torch
import torchcodec
print(f"Success! TorchCodec loaded. CUDA: {torch.cuda.is_available()}")

# ffmpeg_dll_dir = Path(r"D:\Utilities\miniconda\envs\asr\Library\bin")  # adjust if your conda root differs
# assert ffmpeg_dll_dir.exists(), ffmpeg_dll_dir
# os.add_dll_directory(str(ffmpeg_dll_dir))  # Python 3.8+ DLL search

# import torch, torchcodec, platform, subprocess
# print("exe:", sys.executable)
# print("torch", torch.__version__, "torchcodec", torchcodec.__version__, "py", platform.python_version())
# subprocess.run(["ffmpeg", "-version"], check=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 10
#       1 # Use Python's Windows DLL API (3.8+). Add the folder that holds avcodec/avformat/avutil DLLs.
#       2 # TorchCodec README + version matrix: https://github.com/pytorch/torchcodec  (docs)
#       3
#    (...)      6 # # Point this to the 'bin' folder of your 'asr' environment
#       7 # os.add_dll_directory(r"D:\Utilities\miniconda\envs\asr\Library\bin")
#       9 import torch
# ---> 10 import torchcodec
#      11 print(f"Success! TorchCodec loaded. CUDA: {torch.cuda.is_available()}")
#      13 # ffmpeg_dll_dir = Path(r"D:\Utilities\miniconda\envs\asr\Library\bin")  # adjust if your conda root differs
#      14 # assert ffmpeg_dll_dir.exists(), ffmpeg_dll_dir
#      15 # os.add_dll_directory(str(ffmpeg_dll_dir))  # Python 3.8+ DLL search
#    (...)     19 # print("torch", torch.__version__, "torchcodec", torchcodec.__version__, "py", platform.python_version())
#      20 # subprocess.run(["ffmpeg", "-version"], check=True)
#
# File c:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\__init__.py:12
#       9 # Note: usort wants to put Frame and FrameBatch after decoders and samplers,
#      10 # but that results in circular import.
#      11 from ._frame import AudioSamples, Frame, FrameBatch  # usort:skip # noqa
# ---> 12 from . import decoders, encoders, samplers  # noqa
#      14 try:
#      15     # Note that version.py is generated during install.
#      16     from .version import __version__  # noqa: F401
#
# File c:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\decoders\__init__.py:7
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 # All rights reserved.
#       3 #
#       4 # This source code is licensed under the BSD-style license found in the
#       5 # LICENSE file in the root directory of this source tree.
# ----> 7 from .._core import AudioStreamMetadata, VideoStreamMetadata
#       8 from ._audio_decoder import AudioDecoder  # noqa
#       9 from ._decoder_utils import set_cuda_backend  # noqa
#
# File c:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\_core\__init__.py:8
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 # All rights reserved.
#       3 #
#       4 # This source code is licensed under the BSD-style license found in the
#       5 # LICENSE file in the root directory of this source tree.
# ----> 8 from ._metadata import (
#       9     AudioStreamMetadata,
#      10     ContainerMetadata,
#      11     get_container_metadata,
#      12     get_container_metadata_from_header,
#      13     VideoStreamMetadata,
#      14 )
#      15 from .ops import (
#      16     _add_video_stream,
#      17     _get_backend_details,
#    (...)     45     seek_to_pts,
#      46 )
#
# File c:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\_core\_metadata.py:16
#      12 from typing import List, Optional, Union
#      14 import torch
# ---> 16 from torchcodec._core.ops import (
#      17     _get_container_json_metadata,
#      18     _get_stream_json_metadata,
#      19     create_from_file,
#      20 )
#      23 SPACES = "  "
#      26 @dataclass
#      27 class StreamMetadata:
#
# File c:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\_core\ops.py:104
#     100             return os.add_dll_directory(str(ffmpeg_dir))  # that's the actual CM
#     103 with expose_ffmpeg_dlls():
# --> 104     ffmpeg_major_version, core_library_path = load_torchcodec_shared_libraries()
#     107 # Note: We use disallow_in_graph because PyTorch does constant propagation of
#     108 # factory functions.
#     109 create_from_file = torch._dynamo.disallow_in_graph(
#     110     torch.ops.torchcodec_ns.create_from_file.default
#     111 )
#
# File c:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\_core\ops.py:75, in load_torchcodec_shared_libraries()
#      68         exceptions.append((ffmpeg_major_version, e))
#      70 traceback = (
#      71     "\n[start of libtorchcodec loading traceback]\n"
#      72     + "\n".join(f"FFmpeg version {v}: {str(e)}" for v, e in exceptions)
#      73     + "\n[end of libtorchcodec loading traceback]."
#      74 )
# ---> 75 raise RuntimeError(
#      76     f"""Could not load libtorchcodec. Likely causes:
#      77       1. FFmpeg is not properly installed in your environment. We support
#      78          versions 4, 5, 6, 7, and 8. On Windows, ensure you've installed
#      79          the "full-shared" version which ships DLLs.
#      80       2. The PyTorch version ({torch.__version__}) is not compatible with
#      81          this version of TorchCodec. Refer to the version compatibility
#      82          table:
#      83          https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.
#      84       3. Another runtime dependency; see exceptions below.
#      85     The following exceptions were raised as we tried to load libtorchcodec:
#      86     """
#      87     f"{traceback}"
#      88 )
#
# RuntimeError: Could not load libtorchcodec. Likely causes:
#           1. FFmpeg is not properly installed in your environment. We support
#              versions 4, 5, 6, 7, and 8. On Windows, ensure you've installed
#              the "full-shared" version which ships DLLs.
#           2. The PyTorch version (2.9.1+cu128) is not compatible with
#              this version of TorchCodec. Refer to the version compatibility
#              table:
#              https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.
#           3. Another runtime dependency; see exceptions below.
#         The following exceptions were raised as we tried to load libtorchcodec:
#
# [start of libtorchcodec loading traceback]
# FFmpeg version 8: Could not load this library: C:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\libtorchcodec_core8.dll
# FFmpeg version 7: Could not load this library: C:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\libtorchcodec_core7.dll
# FFmpeg version 6: Could not load this library: C:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\libtorchcodec_core6.dll
# FFmpeg version 5: Could not load this library: C:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\libtorchcodec_core5.dll
# FFmpeg version 4: Could not load this library: C:\Users\ACER\miniconda3\envs\dl\Lib\site-packages\torchcodec\libtorchcodec_core4.dll
# [end of libtorchcodec loading traceback].

# %%
# from torchcodec.decoders import VideoDecoder
import torch
print(torch.version.cuda)
print(f"Successfully loaded TorchCodec with CUDA: {torch.cuda.is_available()}")
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
decoder = VideoDecoder("kicking.mp4", device=device)

decoder.metadata

# %%
from torchcodec.samplers import clips_at_regular_timestamps

clips = clips_at_regular_timestamps(
    decoder,
    seconds_between_clip_starts=10, # in 1 video, collect frames / 10s
    num_frames_per_clip=5, # extract 5 frames per clip
    seconds_between_frames=0.2, # frames / 0.2s
)

clips

# %%
from typing import Optional

def plot(frames: torch.Tensor, title : Optional[str] = None):
    try:
        from torchvision.utils import make_grid
        from torchvision.transforms.v2.functional import to_pil_image
        import matplotlib.pyplot as plt
    except ImportError:
        print("Cannot plot, please run `pip install torchvision matplotlib`")
        return

    plt.rcParams["savefig.bbox"] = 'tight'
    fig, ax = plt.subplots()
    ax.imshow(to_pil_image(make_grid(frames)))
    ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])
    if title is not None:
        ax.set_title(title)
    plt.tight_layout()

# %%
for frame in decoder:
    assert (
        isinstance(frame, torch.Tensor)
        and frame.shape == (3, decoder.metadata.height, decoder.metadata.width)
    )

# %%
first_frame = decoder[0]
#? Extract frame Flexibility
every_twenty_frame = decoder[0 : -1 : 20]  # using slices

print(f"{first_frame.shape = }")
print(f"{first_frame.dtype = }")
print(f"{every_twenty_frame.shape = }")
print(f"{every_twenty_frame.dtype = }")

# %%
plot(every_twenty_frame, "every 20")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the Big O cost function based on the snippet
def calculate_update_cost(d_in, L_layer, f_hat):
    # Formula: (1/f_hat) * (L_layer/5) * (d_in^2)
    # We use arbitrary units (AU) for comparison
    return (1 / f_hat) * (L_layer / 5) * (d_in ** 2)

# 1. Setup variables
# Hidden dimensions (d_in) typically range from small (768) to large (8192) in LLMs
d_in_values = np.linspace(768, 8192, 100)

# Scenarios to compare:
# (Label, L_layer, f_hat)
scenarios = [
    ("Base: 12 Layers, f=1", 12, 1),
    ("Deep: 32 Layers, f=1", 32, 1),
    ("Deep + High Freq: 32 Layers, f=16", 32, 16),
    ("Very Deep + High Freq: 96 Layers, f=16", 96, 16),
]

# 2. Plotting
plt.figure(figsize=(12, 7))

for label, L, f in scenarios:
    costs = calculate_update_cost(d_in_values, L, f)
    # Normalize mainly for readability if numbers get huge,
    # but here we keep raw relative values to show scale differences.
    plt.plot(d_in_values, costs, linewidth=2.5, label=f"{label} (L={L}, $\hat{{f}}$={f})")

# 3. Styling the graph
plt.title(r'CMS Average Update Cost: $O(\frac{1}{\hat{f}} \times \frac{L_{layer}}{5} \times d_{in}^2)$', fontsize=16)
plt.xlabel('Hidden Dimension ($d_{in}$)', fontsize=14)
plt.ylabel('Relative Computational Cost (Operations)', fontsize=14)
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.yscale('log') # Log
