# %%
vocab = ['Anthropic', 'best', 'release', 'code', 'ai', 'models']

corpus = [
    "Anthropic is the best",
    "Anthropic release new coding AI models"
]


max_length = len(corpus[1])

def tokenizer(sentence, vocab):
    tokenize_seq = []

    for sentence in corpus:
        sequence = []
        for token in sentence:
            if token not in vocab:
                sequence.append('<unk>')
