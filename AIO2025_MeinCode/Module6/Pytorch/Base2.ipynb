# %% [markdown]
# ## Load Data

# %%
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
import numpy as np
import random

np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %%
batch_size = 512
num_epochs = 15

train_dataset = FashionMNIST('./data', train=True, download=True, transform=transforms.ToTensor())
train_loader = DataLoader(train_dataset, batch_size, shuffle=True)

# %% [markdown]
# ### Update Skip Connection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class SwiGLU(nn.Module):
    def __init__(self):
        super(SwiGLU, self).__init__()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        a, b = x.chunk(2, dim=1)
        return a * self.sigmoid(b)

class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_dims, hidden_dims * 2)
        self.bn1 = nn.BatchNorm1d(hidden_dims * 2)

        self.fc2 = nn.Linear(hidden_dims, hidden_dims * 2)
        self.bn2 = nn.BatchNorm1d(hidden_dims * 2)

        self.fc3 = nn.Linear(hidden_dims, hidden_dims * 2)
        self.bn3 = nn.BatchNorm1d(hidden_dims * 2)

        self.output = nn.Linear(hidden_dims, output_dims)

        for m in self.modules():
            # He initialization
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0.0)

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.fc1(x)
        x = self.bn1(x)
        residual = SwiGLU()(x)


        x = self.fc2(residual)
        x = self.bn2(x)
        x = SwiGLU()(x)

        x = self.fc3(x)
        x = self.bn3(x)
        x = SwiGLU()(x)

        x = x + residual  #? Add Skip Connection to final Hidden Layer

        out = self.output(x)

        return out

# %%
model = MLP(input_dims=784, hidden_dims=128, output_dims=10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
model
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=128, out_features=256, bias=True)
#   (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (output): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
for epoch in range(num_epochs):
    t_loss = 0
    t_acc = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)

        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()

        t_loss += loss.item()
        t_acc += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)

    t_loss /= len(train_loader)
    t_acc /= cnt
    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {t_loss:.4f}, Train_Acc: {t_acc:.4f}")
# Out:
# Epoch 1/15, Train_Loss: 0.5098, Train_Acc: 0.8210
# Epoch 2/15, Train_Loss: 0.3402, Train_Acc: 0.8782
# Epoch 3/15, Train_Loss: 0.2968, Train_Acc: 0.8916
# Epoch 4/15, Train_Loss: 0.2622, Train_Acc: 0.9042
# Epoch 5/15, Train_Loss: 0.2388, Train_Acc: 0.9121
# Epoch 6/15, Train_Loss: 0.2200, Train_Acc: 0.9186
# Epoch 7/15, Train_Loss: 0.2013, Train_Acc: 0.9263
# Epoch 8/15, Train_Loss: 0.1854, Train_Acc: 0.9318
# Epoch 9/15, Train_Loss: 0.1661, Train_Acc: 0.9397
# Epoch 10/15, Train_Loss: 0.1627, Train_Acc: 0.9393
# Epoch 11/15, Train_Loss: 0.1409, Train_Acc: 0.9485
# Epoch 12/15, Train_Loss: 0.1305, Train_Acc: 0.9524
# Epoch 13/15, Train_Loss: 0.1182, Train_Acc: 0.9565
# Epoch 14/15, Train_Loss: 0.1131, Train_Acc: 0.9587
# Epoch 15/15, Train_Loss: 0.1029, Train_Acc: 0.9636
