# %% [markdown]
# [Microsoft HummingBird library to speedup ML with GPU tensor](https://github.com/microsoft/hummingbird)

# %%
# !python -m pip install hummingbird-ml
# Out:
# Collecting hummingbird-ml
#   Downloading hummingbird_ml-0.4.12-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (2.0.2)
# Collecting onnxconverter-common>=1.6.0 (from hummingbird-ml)
#   Downloading onnxconverter_common-1.16.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting onnx<=1.16.1 (from hummingbird-ml)
#   Downloading onnx-1.16.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (1.16.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (1.6.1)
# Requirement already satisfied: torch>1.7.0 in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (2.8.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (5.9.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (0.3.8)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from hummingbird-ml) (5.29.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxconverter-common>=1.6.0->hummingbird-ml) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>1.7.0->hummingbird-ml) (3.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hummingbird-ml) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->hummingbird-ml) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>1.7.0->hummingbird-ml) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>1.7.0->hummingbird-ml) (3.0.2)
# Downloading hummingbird_ml-0.4.12-py2.py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.5/166.5 kB 3.0 MB/s eta 0:00:00
# Downloading onnx-1.16.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 24.3 MB/s eta 0:00:00
# Downloading onnxconverter_common-1.16.0-py2.py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: onnx, onnxconverter-common, hummingbird-ml
# Successfully installed hummingbird-ml-0.4.12 onnx-1.16.1 onnxconverter-common-1.16.0

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from hummingbird.ml import convert, load

# Create some random data for binary classification
num_classes = 2
X = np.random.rand(100000, 28)
y = np.random.randint(num_classes, size=100000)

# Create and train a model (scikit-learn RandomForestClassifier in this case)
skl_model = RandomForestClassifier(n_estimators=10, max_depth=10)
skl_model.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=10)

# %%
skl_model.score(X, y)
# Out:
# 0.59113

# %%
# %timeit skl_model.predict(X)
# Out:
# 103 ms ± 42.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Use Hummingbird to convert the model to PyTorch
model = convert(skl_model, 'pytorch')

# %%
# Run predictions on CPU
# %timeit model.predict(X)
# Out:
# 281 ms ± 99.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Run predictions on GPU
model.to('cuda')
# %timeit model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-704864519.py in <cell line: 0>()
#       1 # Run predictions on GPU
# ----> 2 model.to('cuda')
#       3 get_ipython().run_line_magic('timeit', 'model.predict(X)')
#
# /usr/local/lib/python3.12/dist-packages/hummingbird/ml/containers/sklearn/pytorch_containers.py in to(self, device)
#     192
#     193     def to(self, device):
# --> 194         self.model.to(device)
#     195         return self
#     196
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1367                     raise
#    1368
# -> 1369         return self._apply(convert)
#    1370
#    1371     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     953             # `with torch.no_grad():`
#     954             with torch.no_grad():
# --> 955                 param_applied = fn(param)
#     956             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     957
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in convert(t)
#    1353                         memory_format=convert_to_format,
#    1354                     )
# -> 1355                 return t.to(
#    1356                     device,
#    1357                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     410         if "CUDA_MODULE_LOADING" not in os.environ:
#     411             os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 412         torch._C._cuda_init()
#     413         # Some of the queued calls may reentrantly call _lazy_init();
#     414         # we need to just return without initializing in that case.
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
# Save the model
model.save('hb_model')

# Load the model back
model = load('hb_model')
