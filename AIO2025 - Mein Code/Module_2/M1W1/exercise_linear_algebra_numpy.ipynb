# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
def compute_vector_length(vector: list):
    vector = np.ndarray(vector)

    return vector.shape # return length of vector

# %%
a = [2,3,4]
compute_vector_length(a)
# Out:
# (2, 3, 4)
