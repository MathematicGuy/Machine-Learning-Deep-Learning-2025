# %% [markdown]
# ## **0. Download dataset**
# **Note:** If you can't download using gdown due to limited number of downloads, please download it manually and upload it to your drive, then copy it from the drive to colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/1aQ8OlUljwEm7RLZz8Qf4xzim0nDewHfU/view?usp=sharing
# !gdown --id 1aQ8OlUljwEm7RLZz8Qf4xzim0nDewHfU
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1aQ8OlUljwEm7RLZz8Qf4xzim0nDewHfU
# To: /content/twitter_sentiment_analysis_3cls_dataset.zip
# 100% 7.97M/7.97M [00:00<00:00, 9.09MB/s]

# %%
# !unzip ../content/twitter_sentiment_analysis_3cls_dataset.zip
# Out:
# Archive:  ../content/twitter_sentiment_analysis_3cls_dataset.zip
#   inflating: Twitter_Data.csv

# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import torch
import torch.nn as nn
import torch.optim as optim
import nltk
nltk.download('stopwords')

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## **2. Read dataset**

# %%
dataset_path = '../content/Twitter_Data.csv'
df = pd.read_csv(
    dataset_path
)
df
# Out:
#                                                clean_text  category
# 0       when modi promised “minimum government maximum...      -1.0
# 1       talk all the nonsense and continue all the dra...       0.0
# 2       what did just say vote for modi  welcome bjp t...       1.0
# 3       asking his supporters prefix chowkidar their n...       1.0
# 4       answer who among these the most powerful world...       1.0
# ...                                                   ...       ...
# 162975  why these 456 crores paid neerav modi not reco...      -1.0
# 162976  dear rss terrorist payal gawar what about modi...      -1.0
# 162977  did you cover her interaction forum where she ...       0.0
# 162978  there big project came into india modi dream p...       0.0
# 162979  have you ever listen about like gurukul where ...       1.0
#
# [162980 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162980 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   clean_text  162976 non-null  object
#  1   category    162973 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#             category
# count  162973.000000
# mean        0.225436
# std         0.781279
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# ## **3. Drop missing value**

# %%
null_rows = df.isnull().any(axis=1)
df[null_rows]
# Out:
#                                                clean_text  category
# 148                                                   NaN       0.0
# 130448  the foundation stone northeast gas grid inaugu...       NaN
# 155642  dear terrorists you can run but you cant hide ...       NaN
# 155698  offense the best defence with mission shakti m...       NaN
# 155770  have always heard politicians backing out thei...       NaN
# 158693  modi government plans felicitate the faceless ...       NaN
# 158694                                                NaN      -1.0
# 159442               chidambaram gives praises modinomics       NaN
# 159443                                                NaN       0.0
# 160559  the reason why modi contested from seats 2014 ...       NaN
# 160560                                                NaN       1.0

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162969 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   clean_text  162969 non-null  object
#  1   category    162969 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 3.7+ MB

# %% [markdown]
# ## **4. Preprocessing data**

# %%
def text_normalize(text):
    # Lowercasing
    text = text.lower()

    # Retweet old acronym "RT" removal
    text = re.sub(r'^rt[\s]+', '', text)

    # Hyperlinks removal
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)

    # Punctuation removal
    text = re.sub(r'[^\w\s]', '', text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = text.split()
    words = [word for word in words if word not in stop_words]
    text = ' '.join(words)

    # Stemming
    stemmer = SnowballStemmer('english')
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    text = ' '.join(words)

    return text

# %%
text = """We love this! Would you go?
#talk #makememories #unplug
#relax #iphone #smartphone #wifi #connect...
http://fb.me/6N3LsUpCu
"""
text = text_normalize(text)
text
# Out:
# 'love would go talk makememori unplug relax iphon smartphon wifi connect'

# %%
df['clean_text'] = df['clean_text'].apply(
    lambda x: text_normalize(x)
)
# Out:
# /tmp/ipython-input-141919810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_text'] = df['clean_text'].apply(

# %%
df
# Out:
#                                                clean_text  category
# 0       modi promis minimum govern maximum govern expe...      -1.0
# 1                    talk nonsens continu drama vote modi       0.0
# 2       say vote modi welcom bjp told rahul main campa...       1.0
# 3       ask support prefix chowkidar name modi great s...       1.0
# 4       answer among power world leader today trump pu...       1.0
# ...                                                   ...       ...
# 162975  456 crore paid neerav modi recov congress lead...      -1.0
# 162976  dear rss terrorist payal gawar modi kill 1000 ...      -1.0
# 162977                          cover interact forum left       0.0
# 162978  big project came india modi dream project happ...       0.0
# 162979  ever listen like gurukul disciplin maintain ev...       1.0
#
# [162969 rows x 2 columns]

# %%
vectorizer = TfidfVectorizer(
    max_features=2000
)
X = vectorizer.fit_transform(
    df['clean_text']
).toarray()

# %%
print(X.shape)
# Out:
# (162969, 2000)

# %% [markdown]
# # Bắt đầu bài tập code - Thay thế code vào phần Your Code Here

# %% [markdown]
# ## **5. One-hot encoding label**

# %%
n_classes = ***Your Code Here***
n_samples = ***Your Code Here***

y = ***Your Code Here***
y = y.astype(np.uint8)
y_encoded = np.array(
    ***Your Code Here***]
)
y_encoded[np.arange(n_samples), y] = 1

# %% [markdown]
# ## **6. Create train, val, test set**

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y_encoded, dtype=torch.float32)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    ***Your Code Here***
    test_size=***Your Code Here***,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    ***Your Code Here***
    test_size=***Your Code Here***,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 114078
# Number of val samples: 32594
# Number of test samples: 16297

# %% [markdown]
# ## **7. Define Softmax Regression model**

# %%
class SoftmaxRegression(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SoftmaxRegression, self).__init__()
        self.linear = nn.Linear(
            ***Your Code Here***,
            ***Your Code Here***,
            bias=True
        )

    def forward(self, x):
        return ***Your Code Here***

# %%
def compute_accuracy(y_hat, y_true):
    _, y_hat = torch.max(y_hat, dim=1)
    _, y_true = ***Your Code Here***

    correct = ***Your Code Here***

    accuracy = ***Your Code Here***

    return accuracy

# %% [markdown]
# ## **8. Training**

# %%
lr = 0.1
epochs = 500
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

input_dim = X_train.shape[1]
output_dim = y_train.shape[1]

model = SoftmaxRegression(
    ***Your Code Here***
)
criterion = ***Your Code Here***
optimizer = ***Your Code Here***

# %%
train_losses = []
train_accs = []
val_losses = []
val_accs = []

for epoch in range(epochs):
    model.***Your Code Here***

    # Zero the gradients
    optimizer.zero_grad()

    # Forward pass
    y_hat = model(X_train)

    # Compute loss
    train_loss = ***Your Code Here***

    train_losses.append(train_loss.item())

    train_acc = compute_accuracy(y_hat, y_train)
    train_accs.append(train_acc)

    # Backward pass and optimization
    train_loss.***Your Code Here***
    optimizer.***Your Code Here***

    model.eval()
    # Forward pass for validation data
    with torch.***Your Code Here***:
        y_val_hat = model(X_val)

        # Compute validation loss
        val_loss = criterion(y_val_hat, y_val)
        val_losses.append(val_loss.item())

        val_acc = compute_accuracy(y_val_hat, y_val)
        val_accs.append(val_acc)

    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 1.096	Validation loss: 1.093
#
# EPOCH 2:	Training loss: 1.093	Validation loss: 1.091
#
# EPOCH 3:	Training loss: 1.091	Validation loss: 1.089
#
# EPOCH 4:	Training loss: 1.089	Validation loss: 1.087
#
# EPOCH 5:	Training loss: 1.087	Validation loss: 1.085
#
# EPOCH 6:	Training loss: 1.085	Validation loss: 1.083
#
# EPOCH 7:	Training loss: 1.084	Validation loss: 1.082
#
# EPOCH 8:	Training loss: 1.082	Validation loss: 1.080
#
# EPOCH 9:	Training loss: 1.081	Validation loss: 1.079
#
# EPOCH 10:	Training loss: 1.079	Validation loss: 1.077
#
# EPOCH 11:	Training loss: 1.078	Validation loss: 1.076
#
# EPOCH 12:	Training loss: 1.077	Validation loss: 1.075
#
# EPOCH 13:	Training loss: 1.076	Validation loss: 1.074
#
# EPOCH 14:	Training loss: 1.075	Validation loss: 1.073
#
# EPOCH 15:	Training loss: 1.074	Validation loss: 1.072
#
# EPOCH 16:	Training loss: 1.073	Validation loss: 1.071
#
# EPOCH 17:	Training loss: 1.072	Validation loss: 1.070
#
# EPOCH 18:	Training loss: 1.071	Validation loss: 1.069
#
# EPOCH 19:	Training loss: 1.070	Validation loss: 1.068
#
# EPOCH 20:	Training loss: 1.069	Validation loss: 1.068
#
# EPOCH 21:	Training loss: 1.069	Validation loss: 1.067
#
# EPOCH 22:	Training loss: 1.068	Validation loss: 1.066
#
# EPOCH 23:	Training loss: 1.068	Validation loss: 1.066
#
# EPOCH 24:	Training loss: 1.067	Validation loss: 1.065
#
# EPOCH 25:	Training loss: 1.066	Validation loss: 1.065
#
# EPOCH 26:	Training loss: 1.066	Validation loss: 1.064
#
# EPOCH 27:	Training loss: 1.066	Validation loss: 1.064
#
# EPOCH 28:	Training loss: 1.065	Validation loss: 1.063
#
# EPOCH 29:	Training loss: 1.065	Validation loss: 1.063
#
# EPOCH 30:	Training loss: 1.064	Validation loss: 1.063
#
# EPOCH 31:	Training loss: 1.064	Validation loss: 1.062
#
# EPOCH 32:	Training loss: 1.064	Validation loss: 1.062
#
# EPOCH 33:	Training loss: 1.063	Validation loss: 1.061
#
# EPOCH 34:	Training loss: 1.063	Validation loss: 1.061
#
# EPOCH 35:	Training loss: 1.063	Validation loss: 1.061
#
# EPOCH 36:	Training loss: 1.062	Validation loss: 1.061
#
# EPOCH 37:	Training loss: 1.062	Validation loss: 1.060
#
# EPOCH 38:	Training loss: 1.062	Validation loss: 1.060
#
# EPOCH 39:	Training loss: 1.062	Validation loss: 1.060
#
# EPOCH 40:	Training loss: 1.061	Validation loss: 1.060
#
# EPOCH 41:	Training loss: 1.061	Validation loss: 1.059
#
# EPOCH 42:	Training loss: 1.061	Validation loss: 1.059
#
# EPOCH 43:	Training loss: 1.061	Validation loss: 1.059
#
# EPOCH 44:	Training loss: 1.061	Validation loss: 1.059
#
# EPOCH 45:	Training loss: 1.060	Validation loss: 1.059
#
# EPOCH 46:	Training loss: 1.060	Validation loss: 1.058
#
# EPOCH 47:	Training loss: 1.060	Validation loss: 1.058
#
# EPOCH 48:	Training loss: 1.060	Validation loss: 1.058
#
# EPOCH 49:	Training loss: 1.060	Validation loss: 1.058
#
# EPOCH 50:	Training loss: 1.060	Validation loss: 1.058
#
# EPOCH 51:	Training loss: 1.059	Validation loss: 1.058
#
# EPOCH 52:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 53:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 54:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 55:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 56:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 57:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 58:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 59:	Training loss: 1.059	Validation loss: 1.057
#
# EPOCH 60:	Training loss: 1.058	Validation loss: 1.057
#
# EPOCH 61:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 62:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 63:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 64:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 65:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 66:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 67:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 68:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 69:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 70:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 71:	Training loss: 1.058	Validation loss: 1.056
#
# EPOCH 72:	Training loss: 1.057	Validation loss: 1.056
#
# EPOCH 73:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 74:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 75:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 76:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 77:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 78:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 79:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 80:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 81:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 82:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 83:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 84:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 85:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 86:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 87:	Training loss: 1.057	Validation loss: 1.055
#
# EPOCH 88:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 89:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 90:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 91:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 92:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 93:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 94:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 95:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 96:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 97:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 98:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 99:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 100:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 101:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 102:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 103:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 104:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 105:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 106:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 107:	Training loss: 1.056	Validation loss: 1.054
#
# EPOCH 108:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 109:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 110:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 111:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 112:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 113:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 114:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 115:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 116:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 117:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 118:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 119:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 120:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 121:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 122:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 123:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 124:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 125:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 126:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 127:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 128:	Training loss: 1.055	Validation loss: 1.053
#
# EPOCH 129:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 130:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 131:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 132:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 133:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 134:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 135:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 136:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 137:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 138:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 139:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 140:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 141:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 142:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 143:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 144:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 145:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 146:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 147:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 148:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 149:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 150:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 151:	Training loss: 1.054	Validation loss: 1.052
#
# EPOCH 152:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 153:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 154:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 155:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 156:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 157:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 158:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 159:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 160:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 161:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 162:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 163:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 164:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 165:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 166:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 167:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 168:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 169:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 170:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 171:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 172:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 173:	Training loss: 1.053	Validation loss: 1.051
#
# EPOCH 174:	Training loss: 1.053	Validation loss: 1.050
#
# EPOCH 175:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 176:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 177:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 178:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 179:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 180:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 181:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 182:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 183:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 184:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 185:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 186:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 187:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 188:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 189:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 190:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 191:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 192:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 193:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 194:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 195:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 196:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 197:	Training loss: 1.052	Validation loss: 1.050
#
# EPOCH 198:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 199:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 200:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 201:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 202:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 203:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 204:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 205:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 206:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 207:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 208:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 209:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 210:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 211:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 212:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 213:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 214:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 215:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 216:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 217:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 218:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 219:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 220:	Training loss: 1.051	Validation loss: 1.049
#
# EPOCH 221:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 222:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 223:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 224:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 225:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 226:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 227:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 228:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 229:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 230:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 231:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 232:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 233:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 234:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 235:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 236:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 237:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 238:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 239:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 240:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 241:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 242:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 243:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 244:	Training loss: 1.050	Validation loss: 1.048
#
# EPOCH 245:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 246:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 247:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 248:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 249:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 250:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 251:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 252:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 253:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 254:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 255:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 256:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 257:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 258:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 259:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 260:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 261:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 262:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 263:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 264:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 265:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 266:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 267:	Training loss: 1.049	Validation loss: 1.047
#
# EPOCH 268:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 269:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 270:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 271:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 272:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 273:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 274:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 275:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 276:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 277:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 278:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 279:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 280:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 281:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 282:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 283:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 284:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 285:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 286:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 287:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 288:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 289:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 290:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 291:	Training loss: 1.048	Validation loss: 1.046
#
# EPOCH 292:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 293:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 294:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 295:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 296:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 297:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 298:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 299:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 300:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 301:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 302:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 303:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 304:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 305:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 306:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 307:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 308:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 309:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 310:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 311:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 312:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 313:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 314:	Training loss: 1.047	Validation loss: 1.045
#
# EPOCH 315:	Training loss: 1.046	Validation loss: 1.045
#
# EPOCH 316:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 317:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 318:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 319:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 320:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 321:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 322:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 323:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 324:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 325:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 326:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 327:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 328:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 329:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 330:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 331:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 332:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 333:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 334:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 335:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 336:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 337:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 338:	Training loss: 1.046	Validation loss: 1.044
#
# EPOCH 339:	Training loss: 1.045	Validation loss: 1.044
#
# EPOCH 340:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 341:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 342:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 343:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 344:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 345:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 346:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 347:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 348:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 349:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 350:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 351:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 352:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 353:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 354:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 355:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 356:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 357:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 358:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 359:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 360:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 361:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 362:	Training loss: 1.045	Validation loss: 1.043
#
# EPOCH 363:	Training loss: 1.044	Validation loss: 1.043
#
# EPOCH 364:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 365:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 366:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 367:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 368:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 369:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 370:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 371:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 372:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 373:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 374:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 375:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 376:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 377:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 378:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 379:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 380:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 381:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 382:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 383:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 384:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 385:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 386:	Training loss: 1.044	Validation loss: 1.042
#
# EPOCH 387:	Training loss: 1.043	Validation loss: 1.042
#
# EPOCH 388:	Training loss: 1.043	Validation loss: 1.042
#
# EPOCH 389:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 390:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 391:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 392:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 393:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 394:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 395:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 396:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 397:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 398:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 399:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 400:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 401:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 402:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 403:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 404:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 405:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 406:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 407:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 408:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 409:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 410:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 411:	Training loss: 1.043	Validation loss: 1.041
#
# EPOCH 412:	Training loss: 1.042	Validation loss: 1.041
#
# EPOCH 413:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 414:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 415:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 416:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 417:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 418:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 419:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 420:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 421:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 422:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 423:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 424:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 425:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 426:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 427:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 428:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 429:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 430:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 431:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 432:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 433:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 434:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 435:	Training loss: 1.042	Validation loss: 1.040
#
# EPOCH 436:	Training loss: 1.041	Validation loss: 1.040
#
# EPOCH 437:	Training loss: 1.041	Validation loss: 1.040
#
# EPOCH 438:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 439:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 440:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 441:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 442:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 443:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 444:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 445:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 446:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 447:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 448:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 449:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 450:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 451:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 452:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 453:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 454:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 455:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 456:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 457:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 458:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 459:	Training loss: 1.041	Validation loss: 1.039
#
# EPOCH 460:	Training loss: 1.040	Validation loss: 1.039
#
# EPOCH 461:	Training loss: 1.040	Validation loss: 1.039
#
# EPOCH 462:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 463:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 464:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 465:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 466:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 467:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 468:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 469:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 470:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 471:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 472:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 473:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 474:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 475:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 476:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 477:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 478:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 479:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 480:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 481:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 482:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 483:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 484:	Training loss: 1.040	Validation loss: 1.038
#
# EPOCH 485:	Training loss: 1.039	Validation loss: 1.038
#
# EPOCH 486:	Training loss: 1.039	Validation loss: 1.038
#
# EPOCH 487:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 488:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 489:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 490:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 491:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 492:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 493:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 494:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 495:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 496:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 497:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 498:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 499:	Training loss: 1.039	Validation loss: 1.037
#
# EPOCH 500:	Training loss: 1.039	Validation loss: 1.037

# %% [markdown]
# # Done bài tập code - Phần sau chỉ cần đọc và Run Cell

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **9. Evaluation**

# %%
# Val set
model.eval()
with torch.no_grad():
    y_hat = model(X_val)
    val_set_acc = compute_accuracy(y_hat, y_val)
    print('Evaluation on validation set:')
    print(f'Accuracy: {val_set_acc}')
# Out:
# Evaluation on validation set:
# Accuracy: 0.4506350862121863

# %%
# Test set
model.eval()
with torch.no_grad():
    y_hat = model(X_test)
    test_set_acc = compute_accuracy(y_hat, y_test)
    print('Evaluation on test set:')
    print(f'Accuracy: {test_set_acc}')
# Out:
# Evaluation on test set:
# Accuracy: 0.4491010615450696
