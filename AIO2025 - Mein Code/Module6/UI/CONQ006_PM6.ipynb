# %% [markdown]
# # **1. Setup data:**

# %%
# download data: FPT_train
# FPT_train
# !gdown --id 1l2TtEaWrp4yieMDWE4Cmehnf5mLx3rop

# %% [markdown]
# # **2. Code**

# %%
# ============================================================
# FPT Forecast : Hybrid + Pricing
#
#  - Data:
#       * FPT_train.csv:  FPT OHLCV
#
#  - Pipeline:
#       1) [PREPROCESS] sanity checks + clean time axis + remove duplicates/outliers
#       2) FE: STL + OHLCV + patterns
#       3) Math backbone (trend trên log(close)):
#           - future_ret_math = trend_log_{t+1} - trend_log_t
#       4) ML residual:
#           - XGB học residual: resid_ret = future_ret_real - future_ret_math
#           - future_ret_final = future_ret_math_forecast + xgb_resid_pred
#       5) Hybrid raw path:
#           - build_raw_base_path_hybrid() H=100 ngày (recursive)
#       6) Pricing-layer (regime-aware, pure FPT):
#           - Clip return theo history, half-life damping, mean-revert quanh MA60
#           - Regime BULL/BEAR/SIDEWAYS từ FPT:
#               * price vs MA120
#               * vol_20 vs vol_all
#           - Random search trên pricing params:
#               * Multi-cutoff CV (2020–2024, tháng 3/6/9/12)
#               * Metric = 0.5 * MSE_50 + 0.5 * MSE_100
#       7) FINAL MODEL:
#           - [TRAIN] Train XGB residual trên full FPT_train
#           - [FORECAST] Hybrid raw path H=100 ngày
#           - [FORECAST] Áp pricing-best để ra BASE path
#           - [FORECAST] TREND (linear price), UNCERT analytic, ensemble 70–25–5
#
#  - Outputs:
#       * FPT_forecast.csv
#       * submission.csv (id, close = central_det)
#
#  NOTE:
#       - Pricing-layer được chọn bằng time-series CV trên chính FPT_train.
# ============================================================

# %% [markdown]
# ## **Data Preprocessing & Plot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def preprocess_fpt_train(df_raw: pd.DataFrame,
                         clip_logret: float = 0.20,
                         do_clip: bool = True,
                         verbose: bool = True) -> tuple[pd.DataFrame, dict]:
    """
    Preprocess tối thiểu cho pipeline Hybrid (không phải ARIMA-style).
    Mục tiêu: clean time-axis + sanity check OHLCV + xử lý missing/outlier thô.

    Returns:
      df_clean, report(dict)
    """
    df0 = df_raw.copy()

    # -------------------------
    # (1) time parse + sort + duplicates
    # -------------------------
    if "time" not in df0.columns:
        raise ValueError("[PREPROCESS] Missing column: time")

    df0["time"] = pd.to_datetime(df0["time"], errors="coerce")
    n_bad_time = int(df0["time"].isna().sum())
    df0 = df0.dropna(subset=["time"]).sort_values("time").reset_index(drop=True)

    n_dup_before = int(df0.duplicated(subset=["time"]).sum())
    df0 = df0.drop_duplicates(subset=["time"], keep="last").reset_index(drop=True)

    # -------------------------
    # (2) ensure numeric OHLCV
    # -------------------------
    for c in ["open", "high", "low", "close", "volume"]:
        if c in df0.columns:
            df0[c] = pd.to_numeric(df0[c], errors="coerce")

    if "close" not in df0.columns:
        raise ValueError("[PREPROCESS] Missing column: close")

    # -------------------------
    # (3) sanity checks (count)
    # -------------------------
    has_ohlc = all(c in df0.columns for c in ["open", "high", "low"])
    has_vol = "volume" in df0.columns

    bad_close = df0["close"].isna() | (df0["close"] <= 0)
    n_bad_close = int(bad_close.sum())

    n_bad_high = 0
    n_bad_low = 0
    if has_ohlc:
        bad_high = df0["high"].isna() | (df0["high"] < df0[["open", "close"]].max(axis=1))
        bad_low  = df0["low"].isna()  | (df0["low"]  > df0[["open", "close"]].min(axis=1))
        n_bad_high = int(bad_high.sum())
        n_bad_low  = int(bad_low.sum())

    n_bad_vol = 0
    if has_vol:
        bad_vol = df0["volume"].isna() | (df0["volume"] < 0)
        n_bad_vol = int(bad_vol.sum())

    # -------------------------
    # (3b) fix OHLC projection + volume <0
    # -------------------------
    df1 = df0.copy()

    if has_ohlc:
        # project high/low to satisfy constraints
        df1["high"] = np.maximum(df1["high"], df1[["open", "close"]].max(axis=1))
        df1["low"]  = np.minimum(df1["low"],  df1[["open", "close"]].min(axis=1))

    if has_vol:
        df1.loc[df1["volume"] < 0, "volume"] = np.nan

    # -------------------------
    # (4) missing handling: ffill/bfill only on numeric
    # -------------------------
    num_cols = [c for c in ["open", "high", "low", "close", "volume"] if c in df1.columns]
    if num_cols:
        df1[num_cols] = df1[num_cols].ffill().bfill()

    # drop if still invalid close
    df1 = df1.dropna(subset=["close"]).reset_index(drop=True)
    df1 = df1[df1["close"] > 0].reset_index(drop=True)

    # -------------------------
    # (5) optional anti-spike clip on 1d log-return
    # -------------------------
    n_clip = 0
    if do_clip and len(df1) >= 3:
        close = df1["close"].values.astype(float)
        logp = np.log(close + 1e-8)
        ret1 = np.diff(logp, prepend=logp[0])
        ret1_clip = np.clip(ret1, -clip_logret, clip_logret)
        n_clip = int(np.sum(ret1 != ret1_clip))

        if n_clip > 0:
            logp2 = np.empty_like(logp)
            logp2[0] = logp[0]
            for i in range(1, len(logp2)):
                logp2[i] = logp2[i-1] + ret1_clip[i]
            df1["close"] = np.exp(logp2)

            # if OHLC exists, keep it "reasonable" with a light projection
            if has_ohlc:
                # open as prev close (simple), then re-project highs/lows
                df1["open"] = df1["close"].shift(1).fillna(df1["close"])
                df1["high"] = np.maximum(df1["high"], df1[["open", "close"]].max(axis=1))
                df1["low"]  = np.minimum(df1["low"],  df1[["open", "close"]].min(axis=1))

    report = {
        "n_rows_raw": int(len(df_raw)),
        "n_rows_after_time_parse": int(len(df0)),
        "n_bad_time": n_bad_time,
        "n_dup_days_removed": n_dup_before,
        "n_bad_close_before": n_bad_close,
        "has_ohlc": bool(has_ohlc),
        "n_bad_high_before": n_bad_high,
        "n_bad_low_before": n_bad_low,
        "has_volume": bool(has_vol),
        "n_bad_volume_before": n_bad_vol,
        "do_clip": bool(do_clip),
        "clip_logret": float(clip_logret),
        "n_returns_clipped": int(n_clip),
        "final_shape": tuple(df1.shape),
        "final_range": (df1["time"].min(), df1["time"].max()),
    }

    if verbose:
        a, b = report["final_range"]
        print("========== PREPROCESS REPORT ==========")
        print(f"Raw rows: {report['n_rows_raw']}")
        print(f"Bad time: {report['n_bad_time']} | Duplicates removed: {report['n_dup_days_removed']}")
        print(f"Bad close (NaN/<=0) before fill: {report['n_bad_close_before']}")
        if has_ohlc:
            print(f"OHLC issues before projection: bad_high={report['n_bad_high_before']}, bad_low={report['n_bad_low_before']}")
        if has_vol:
            print(f"Bad volume (NaN/<0) before fill: {report['n_bad_volume_before']}")
        if do_clip:
            print(f"Clipped extreme 1d log-returns: {report['n_returns_clipped']} (threshold=±{clip_logret})")
        print(f"Final: shape={report['final_shape']} | range={a.date()} -> {b.date()}")
        print("======================================")

    return df1, report


def plot_preprocess_effect(df_raw: pd.DataFrame,
                           df_clean: pd.DataFrame,
                           clip_logret: float = 0.20):
    """
    Plot trực quan: raw vs clean.
    """
    # Align on time intersection để plot đẹp (tránh lệch index)
    r = df_raw.copy()
    r["time"] = pd.to_datetime(r["time"], errors="coerce")
    r = r.dropna(subset=["time"]).sort_values("time").drop_duplicates("time", keep="last")
    c = df_clean.copy().sort_values("time").drop_duplicates("time", keep="last")

    rr = r.set_index("time")
    cc = c.set_index("time")

    idx = rr.index.intersection(cc.index)
    rr = rr.loc[idx]
    cc = cc.loc[idx]

    # --- Plot 1: Close ---
    plt.figure(figsize=(14,5))
    plt.plot(rr.index, rr["close"].astype(float), label="close (raw)", alpha=0.6)
    plt.plot(cc.index, cc["close"].astype(float), label="close (clean)", linewidth=2)
    plt.title("Preprocess Effect: Close (raw vs clean)")
    plt.xlabel("Time"); plt.ylabel("Price")
    plt.grid(alpha=0.3); plt.legend(); plt.tight_layout()
    plt.show()

    # --- Plot 2: 1d log-return ---
    def logret1(s):
        s = s.astype(float).values
        lp = np.log(s + 1e-8)
        return np.diff(lp, prepend=lp[0])

    ret_raw = logret1(rr["close"])
    ret_clean = logret1(cc["close"])

    plt.figure(figsize=(14,5))
    plt.plot(rr.index, ret_raw, label="logret_1d (raw)", alpha=0.5)
    plt.plot(cc.index, ret_clean, label="logret_1d (clean)", alpha=0.9)
    plt.axhline(+clip_logret, linestyle="--", linewidth=1, label=f"+clip {clip_logret}")
    plt.axhline(-clip_logret, linestyle="--", linewidth=1, label=f"-clip {clip_logret}")
    plt.title("Preprocess Effect: 1-day log-return (raw vs clean)")
    plt.xlabel("Time"); plt.ylabel("log-return")
    plt.grid(alpha=0.3); plt.legend(); plt.tight_layout()
    plt.show()

    # --- Plot 3: OHLC sanity count (if available) ---
    has_ohlc_raw = all(k in rr.columns for k in ["open","high","low","close"])
    has_ohlc_clean = all(k in cc.columns for k in ["open","high","low","close"])
    if has_ohlc_raw and has_ohlc_clean:
        bad_high_raw = (rr["high"] < rr[["open","close"]].max(axis=1)) | rr["high"].isna()
        bad_low_raw  = (rr["low"]  > rr[["open","close"]].min(axis=1)) | rr["low"].isna()
        bad_high_clean = (cc["high"] < cc[["open","close"]].max(axis=1)) | cc["high"].isna()
        bad_low_clean  = (cc["low"]  > cc[["open","close"]].min(axis=1)) | cc["low"].isna()

        labels = ["bad_high", "bad_low"]
        raw_counts = [int(bad_high_raw.sum()), int(bad_low_raw.sum())]
        clean_counts = [int(bad_high_clean.sum()), int(bad_low_clean.sum())]

        x = np.arange(len(labels))
        w = 0.35

        plt.figure(figsize=(8,4))
        plt.bar(x - w/2, raw_counts, width=w, label="raw")
        plt.bar(x + w/2, clean_counts, width=w, label="clean")
        plt.xticks(x, labels)
        plt.title("OHLC Sanity Violations: raw vs clean (count)")
        plt.ylabel("Count")
        plt.grid(axis="y", alpha=0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()


# ======================
# USAGE (example)
# ======================
df_raw = pd.read_csv("FPT_train.csv")
df_clean, rep = preprocess_fpt_train(df_raw, clip_logret=0.20, do_clip=True, verbose=True)
plot_preprocess_effect(df_raw, df_clean, clip_logret=0.20)
# Out:
# ========== PREPROCESS REPORT ==========
# Raw rows: 1149
# Bad time: 0 | Duplicates removed: 0
# Bad close (NaN/<=0) before fill: 0
# OHLC issues before projection: bad_high=0, bad_low=0
# Bad volume (NaN/<0) before fill: 0
# Clipped extreme 1d log-returns: 0 (threshold=±0.2)
# Final: shape=(1149, 7) | range=2020-08-03 -> 2025-03-10
# ======================================

# %% [markdown]
# ## **2.0. IMPORT & GLOBAL CONFIG**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import random
from dataclasses import dataclass
from typing import List, Optional, Tuple

from statsmodels.tsa.seasonal import STL
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from pandas.tseries.offsets import BDay

warnings.filterwarnings("ignore")

# %%
SEED = 98 # 9 = Cửu, 8 = Bát. 98 = Cửu Bát = Mãi Phát
random.seed(SEED)
np.random.seed(SEED)

FPT_TRAIN_PATH = "FPT_train.csv"

# Nếu muốn test generalization, ép chỉ train tới 1 ngày nào đó:
# FORCE_TRAIN_END_DATE = "2024-10-06"
FORCE_TRAIN_END_DATE = None          # nếu muốn "cắt" train đến 1 ngày cố định

TOTAL_PREDICT_DAYS = 100             # horizon chính khi forecast
HORIZON = 1                          # future_ret = T+1
STL_PERIOD = 20                      # ~1 tháng giao dịch

# Uncertainty band (analytic)
UNCERT_Z = 1.28155                   # ~90% interval

# CV config (dùng cho Pricing-layer)
CV_START_YEAR = 2020
CV_END_YEAR = 2024
CV_HORIZON = 100                     # forecast H ngày trong CV (same as competition horizon)
N_RANDOM_TRIALS = 120                # số cấu hình pricing-layer thử

# %% [markdown]
# ## **2.1. DATA PREPROCESSING**

# %%
def preprocess_fpt_train(df_raw: pd.DataFrame) -> pd.DataFrame:
    """
    Preprocess tối thiểu cho pipeline.
    Mục tiêu: clean time-axis + sanity check OHLCV + xử lý missing/outlier

    Steps:
      (1) Parse time, sort, drop duplicate days
      (2) Ensure numeric OHLCV
      (3) Sanity check:
          - close > 0
          - high >= max(open, close) ; low <= min(open, close)
          - volume >= 0
      (4) Missing handling: forward-fill
      (5) Optional: clip extreme 1-day returns để tránh data lỗi phá STL/rolling
    """
    df = df_raw.copy()

    # (1) time parse + sort + drop duplicates
    if "time" not in df.columns:
        raise ValueError("[PREPROCESS] Missing column: time")

    df["time"] = pd.to_datetime(df["time"], errors="coerce")
    df = df.dropna(subset=["time"]).sort_values("time").reset_index(drop=True)

    # Nếu dữ liệu có nhiều dòng cùng ngày -> lấy dòng cuối (hoặc mean)
    df = df.drop_duplicates(subset=["time"], keep="last").reset_index(drop=True)

    # (2) ensure numeric
    for c in ["open", "high", "low", "close", "volume"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")

    # (3) sanity checks cơ bản
    if "close" not in df.columns:
        raise ValueError("[PREPROCESS] Missing column: close")

    # close phải > 0
    bad_close = df["close"].isna() | (df["close"] <= 0)
    if bad_close.any():
        n_bad = int(bad_close.sum())
        print(f"[PREPROCESS] Found {n_bad} bad close (NaN/<=0). Will forward-fill then drop if needed.")

    # OHLC constraints
    has_ohlc = all(c in df.columns for c in ["open", "high", "low"])
    if has_ohlc:
        # high >= max(open, close)
        bad_high = df["high"].isna() | (df["high"] < df[["open", "close"]].max(axis=1))
        # low <= min(open, close)
        bad_low  = df["low"].isna() | (df["low"]  > df[["open", "close"]].min(axis=1))
        if bad_high.any() or bad_low.any():
            print(f"[PREPROCESS] OHLC sanity issue: bad_high={int(bad_high.sum())}, bad_low={int(bad_low.sum())}. Fixing by projection.")
            # Project sửa thô: ép high/low về hợp lệ
            df["high"] = np.maximum(df["high"], df[["open", "close"]].max(axis=1))
            df["low"]  = np.minimum(df["low"],  df[["open", "close"]].min(axis=1))

    # volume >= 0
    if "volume" in df.columns:
        bad_vol = df["volume"].isna() | (df["volume"] < 0)
        if bad_vol.any():
            print(f"[PREPROCESS] Found {int(bad_vol.sum())} bad volume (NaN/<0). Will fill.")
            df.loc[df["volume"] < 0, "volume"] = np.nan

    # (4) Missing handling (safe: forward fill -> backward fill)
    # Chỉ fill trong cột numeric.
    num_cols = [c for c in ["open", "high", "low", "close", "volume"] if c in df.columns]
    if num_cols:
        df[num_cols] = df[num_cols].ffill().bfill()

    # drop nếu vẫn còn NaN ở close
    df = df.dropna(subset=["close"]).reset_index(drop=True)
    df = df[df["close"] > 0].reset_index(drop=True)

    # (5) Optional anti-spike: clip log-return 1d cực rộng
    # Mục tiêu: nếu data có 1 ngày giá nhảy lỗi (gấp 3–10 lần) thì đừng cho nó phá STL.
    close = df["close"].values.astype(float)
    logp = np.log(close + 1e-8)
    ret1 = np.diff(logp, prepend=logp[0])
    # clip rộng: +-20% log-return/day ~ cực kỳ rộng cho cổ phiếu
    ret1_clip = np.clip(ret1, -0.20, 0.20)
    if np.any(ret1 != ret1_clip):
        n_clip = int(np.sum(ret1 != ret1_clip))
        print(f"[PREPROCESS] Clipped {n_clip} extreme 1d log-returns (anti bad-tick).")
        # reconstruct close (giữ close[0], update theo ret clip)
        logp2 = np.empty_like(logp)
        logp2[0] = logp[0]
        for i in range(1, len(logp2)):
            logp2[i] = logp2[i-1] + ret1_clip[i]
        df["close"] = np.exp(logp2)

        # Projection lại cho hợp lệ
        if has_ohlc:
            df["open"] = df["close"].shift(1).fillna(df["close"])
            df["high"] = np.maximum(df["high"], df[["open", "close"]].max(axis=1))
            df["low"]  = np.minimum(df["low"],  df[["open", "close"]].min(axis=1))

    print(f"[PREPROCESS] Done. Range: {df['time'].min().date()} -> {df['time'].max().date()}, shape={df.shape}")
    return df

# %% [markdown]
# ## **2.2. FEATURE ENGINEERING**

# %%
def add_stl_ohlcv_features(df_raw: pd.DataFrame,
                           stl_period: int = STL_PERIOD) -> pd.DataFrame:
    """
    FE cho FPT OHLCV:
      - close_log
      - Price action OHLC: body, range, shadows, gaps, range_pct, ATR, Parkinson
      - Volume & money flow
      - STL trend/seasonal/resid
      - Returns: ret_1d, ret_5d, ret_10d
      - Patterns: up/down, 3-streak
      - Trend slopes, accel, rolling stats, z-score
    """
    df = df_raw.copy()
    if "close" not in df.columns:
        raise ValueError("DataFrame phải có cột 'close'.")

    df["close"] = df["close"].astype(float)
    df["close_log"] = np.log(df["close"] + 1e-8)
    eps = 1e-6

    # --- Price action từ OHLC ---
    has_ohlc = all(c in df.columns for c in ["open", "high", "low"])
    pa_cols = [
        "body",
        "range",
        "upper_shadow",
        "lower_shadow",
        "body_rel",
        "close_pos",
        "gap_oc",
        "gap_prev_close",
        "range_pct",
        "true_range",
        "atr_14",
        "park_vol",
        "range_ma_10",
        "range_expansion",
        "body_lag1",
        "body_lag2",
        "close_pos_lag1",
    ]
    if has_ohlc:
        df["open"] = df["open"].astype(float)
        df["high"] = df["high"].astype(float)
        df["low"] = df["low"].astype(float)

        df["body"] = df["close"] - df["open"]
        df["range"] = df["high"] - df["low"]
        df["body_rel"] = df["body"] / (df["range"].abs() + eps)

        df["upper_shadow"] = df["high"] - df[["open", "close"]].max(axis=1)
        df["lower_shadow"] = df[["open", "close"]].min(axis=1) - df["low"]
        df["close_pos"] = (df["close"] - df["low"]) / (df["range"].abs() + eps)

        df["gap_oc"] = df["open"] - df["close"]
        df["gap_prev_close"] = df["open"] - df["close"].shift(1)

        prev_close = df["close"].shift(1)
        df["range_pct"] = df["range"] / (prev_close.abs() + eps)

        tr1 = (df["high"] - df["low"]).abs()
        tr2 = (df["high"] - prev_close).abs()
        tr3 = (df["low"] - prev_close).abs()
        df["true_range"] = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
        df["atr_14"] = df["true_range"].rolling(14).mean()

        ratio_hl = (df["high"] / (df["low"] + eps)).clip(lower=eps)
        df["park_vol"] = (1.0 / (4.0 * np.log(2.0))) * (np.log(ratio_hl) ** 2)

        df["range_ma_10"] = df["range"].rolling(10).mean()
        df["range_expansion"] = (df["range"] > 1.5 * (df["range_ma_10"].abs() + eps)).astype(float)

        df["body_lag1"] = df["body"].shift(1)
        df["body_lag2"] = df["body"].shift(2)
        df["close_pos_lag1"] = df["close_pos"].shift(1)
    else:
        for c in pa_cols:
            df[c] = 0.0

    # --- Volume & money flow ---
    vol_cols = [
        "volume",
        "vol_ma_5",
        "vol_ma_20",
        "vol_ratio",
        "money_flow",
        "money_flow_5",
        "vol_z_20",
        "obv",
        "vol_ratio_lag1",
        "obv_diff_1d",
    ]
    if "volume" in df.columns:
        df["volume"] = df["volume"].astype(float)
        df["vol_ma_5"] = df["volume"].rolling(5).mean()
        df["vol_ma_20"] = df["volume"].rolling(20).mean()
        df["vol_ratio"] = df["volume"] / (df["vol_ma_20"].abs() + eps)
        df["money_flow"] = df["close"] * df["volume"]
        df["money_flow_5"] = df["money_flow"].rolling(5).mean()
        df["vol_z_20"] = (df["volume"] - df["vol_ma_20"]) / (df["vol_ma_20"].abs() + eps)

        sign = np.sign(df["close"].diff(1))
        df["obv"] = (sign * df["volume"]).fillna(0).cumsum()

        df["vol_ratio_lag1"] = df["vol_ratio"].shift(1)
        df["obv_diff_1d"] = df["obv"].diff(1)
    else:
        for c in vol_cols:
            df[c] = 0.0

    # --- STL trên close_log ---
    close_log = df["close_log"].copy()
    if close_log.isna().any():
        close_log = close_log.fillna(method="ffill").fillna(method="bfill")

    res = STL(close_log.values, period=stl_period, robust=True).fit()
    df["trend_stl"] = res.trend
    df["seasonal_stl"] = res.seasonal
    df["resid_stl"] = res.resid

    # --- Returns ---
    df["ret_1d"] = df["close_log"].diff(1)
    df["ret_5d"] = df["close_log"].diff(5)
    df["ret_10d"] = df["close_log"].diff(10)

    # --- Patterns ---
    df["up_1d"] = (df["ret_1d"] > 0).astype(float)
    df["down_1d"] = (df["ret_1d"] < 0).astype(float)
    df["up_3streak"] = (
        (df["ret_1d"] > 0)
        & (df["ret_1d"].shift(1) > 0)
        & (df["ret_1d"].shift(2) > 0)
    ).astype(float)
    df["down_3streak"] = (
        (df["ret_1d"] < 0)
        & (df["ret_1d"].shift(1) < 0)
        & (df["ret_1d"].shift(2) < 0)
    ).astype(float)

    # --- Trend slopes & stats ---
    df["trend_slope_1"] = df["trend_stl"].diff(1)
    df["trend_slope_3"] = df["trend_stl"].diff(3)
    df["trend_slope_7"] = df["trend_stl"].diff(7)

    df["trend_accel_3"] = df["trend_slope_1"] - df["trend_slope_1"].shift(3)

    df["trend_mean_21"] = df["trend_stl"].rolling(21).mean()
    df["trend_std_21"] = df["trend_stl"].rolling(21).std(ddof=0)
    df["resid_std_10"] = df["resid_stl"].rolling(10).std(ddof=0)
    df["resid_std_20"] = df["resid_stl"].rolling(20).std(ddof=0)

    df["z_trend_21"] = (df["trend_stl"] - df["trend_mean_21"]) / (df["trend_std_21"] + eps)

    return df


def get_feature_cols() -> List[str]:
    base_cols = [
        "close_log",
        "ret_1d",
        "ret_5d",
        "ret_10d",
        "up_1d",
        "down_1d",
        "up_3streak",
        "down_3streak",
        "trend_stl",
        "trend_slope_1",
        "trend_slope_3",
        "trend_slope_7",
        "trend_accel_3",
        "trend_mean_21",
        "trend_std_21",
        "resid_std_10",
        "resid_std_20",
        "z_trend_21",
        "body",
        "range",
        "upper_shadow",
        "lower_shadow",
        "body_rel",
        "close_pos",
        "gap_oc",
        "gap_prev_close",
        "range_pct",
        "range_ma_10",
        "range_expansion",
        "body_lag1",
        "body_lag2",
        "close_pos_lag1",
        "true_range",
        "atr_14",
        "park_vol",
        "volume",
        "vol_ma_5",
        "vol_ma_20",
        "vol_ratio",
        "vol_ratio_lag1",
        "money_flow",
        "money_flow_5",
        "vol_z_20",
        "obv",
        "obv_diff_1d",
    ]
    return base_cols


def build_modeling_df(
    df_slice: pd.DataFrame,
    stl_period: int,
    horizon: int,
) -> Tuple[pd.DataFrame, pd.DataFrame, List[str]]:
    """
    [FE + LABEL] – dùng cho TRAIN (cả cutoff + final model).

    - future_ret: log(P_{t+h}) - log(P_t)
    - math_ret:   trend_log_{t+h} - trend_log_t (linear trend trên log-price)
    - resid_ret:  future_ret - math_ret  (target cho XGB residual)
    """
    df_slice = df_slice.sort_values("time").reset_index(drop=True)
    df_feat = add_stl_ohlcv_features(df_slice, stl_period=stl_period)
    feature_cols = get_feature_cols()

    # target future_ret
    df_feat["time_future"] = df_feat["time"].shift(-horizon)
    df_feat["close_log_future"] = df_feat["close_log"].shift(-horizon)
    df_feat["future_ret"] = df_feat["close_log_future"] - df_feat["close_log"]

    # Math backbone: linear trend trên log-price
    time_idx = np.arange(len(df_feat)).reshape(-1, 1)
    y_log = df_feat["close_log"].values.reshape(-1, 1)
    lr = LinearRegression()
    lr.fit(time_idx, y_log)
    trend_log = lr.predict(time_idx).flatten()
    df_feat["trend_log"] = trend_log
    df_feat["trend_log_future"] = df_feat["trend_log"].shift(-horizon)
    df_feat["math_ret"] = df_feat["trend_log_future"] - df_feat["trend_log"]

    # Residual target
    df_feat["resid_ret"] = df_feat["future_ret"] - df_feat["math_ret"]

    # Modeling DF: drop rows thiếu
    df_model = df_feat.dropna(
        subset=feature_cols + ["future_ret", "math_ret", "resid_ret", "time_future"]
    ).reset_index(drop=True)

    print("Modeling DF shape:", df_model.shape)
    return df_feat, df_model, feature_cols

# %% [markdown]
# ## **2.3. MODEL STRUCTS**

# %%
@dataclass
class CutoffModel:
    cutoff_time: pd.Timestamp
    xgb: XGBRegressor
    scaler_X: StandardScaler
    feature_cols: List[str]
    df_hist: pd.DataFrame          # OHLCV <= cutoff
    df_feat: pd.DataFrame          # FE <= cutoff
    raw_base_prices_cv: np.ndarray # raw base path hybrid cho CV_HORIZON
    raw_base_rets_cv: np.ndarray   # hybrid future_ret path cho CV_HORIZON


@dataclass
class PricingParams:
    ret_clip_quantile: float
    half_life_days: int
    mean_revert_alpha: float
    mean_revert_start: int
    fair_up_mult: float
    fair_down_mult: float
    trend_lookback: int
    trend_ret_thresh: float


@dataclass
class FinalBaseModel:
    xgb: XGBRegressor
    scaler_X: StandardScaler
    feature_cols: List[str]
    df_train: pd.DataFrame      # OHLCV train (pure FPT)
    df_feat: pd.DataFrame       # FE train
    train_end_date: pd.Timestamp
    resid_std: float
    resid_mean: float

# %% [markdown]
# ## **2.4. TRAIN XGB RESIDUAL  [TRAIN + nội bộ EVAL]**

# %%
def train_xgb_on_dfmodel(
    df_model: pd.DataFrame,
    feature_cols: List[str]
) -> Tuple[XGBRegressor, StandardScaler, float, float]:
    """
    [TRAIN] Train XGB trên resid_ret = future_ret - math_ret.
    Đồng thời in ra MSE/MAE trên train/val/test (nội bộ).
    """
    if len(df_model) < 200:
        raise ValueError(f"[XGB] Too few samples: {len(df_model)}")

    X_all = df_model[feature_cols].values.astype(np.float32)
    y_resid = df_model["resid_ret"].values.astype(np.float32)

    N = len(df_model)
    train_ratio = 0.8
    val_ratio = 0.1

    train_end = int(N * train_ratio)
    val_end = int(N * (train_ratio + val_ratio))

    X_train = X_all[:train_end]
    y_train = y_resid[:train_end]
    X_val = X_all[train_end:val_end]
    y_val = y_resid[train_end:val_end]
    X_test = X_all[val_end:]
    y_test = y_resid[val_end:]

    scaler_X = StandardScaler().fit(X_train)
    X_train_s = scaler_X.transform(X_train)
    X_val_s = scaler_X.transform(X_val)
    X_test_s = scaler_X.transform(X_test)

    xgb = XGBRegressor(
        n_estimators=450,
        max_depth=4,
        learning_rate=0.03,
        subsample=0.9,
        colsample_bytree=0.9,
        reg_lambda=2.0,
        min_child_weight=3,
        objective="reg:squarederror",
        random_state=SEED,
    )
    xgb.fit(X_train_s, y_train)

    # ------- nội bộ EVAL trên resid_ret -------
    def eval_block(name, X_s, y_true):
        if len(y_true) == 0:
            print(f"{name}: empty")
            return
        y_pred = xgb.predict(X_s)
        mse = mean_squared_error(y_true, y_pred)
        mae = mean_absolute_error(y_true, y_pred)
        print(f"{name} (resid) -> MSE: {mse:.6e} | MAE: {mae:.6e}")

    print(f"=== XGB RESIDUAL MODEL ({len(df_model)} samples) ===")
    eval_block("Train", X_train_s, y_train)
    eval_block("Val",   X_val_s,   y_val)
    eval_block("Test",  X_test_s,  y_test)

    # residuals full để tính sigma / mean cho Risk Expert
    y_pred_all = xgb.predict(scaler_X.transform(X_all))
    residuals = y_resid - y_pred_all
    resid_std = float(np.std(residuals, ddof=1))
    resid_mean = float(np.mean(residuals))

    print(f"[RESID] std={resid_std:.6e}, mean={resid_mean:.6e}")
    return xgb, scaler_X, resid_std, resid_mean

# %% [markdown]
# ## **2.5. RAW BASE PATH HYBRID (MATH + XGB)  [FORECAST building block]**

# %%
def build_raw_base_path_hybrid(
    df_hist: pd.DataFrame,
    xgb: XGBRegressor,
    scaler_X: StandardScaler,
    feature_cols: List[str],
    total_days: int,
    stl_period: int = STL_PERIOD,
) -> Tuple[np.ndarray, np.ndarray]:
    """
    [FORECAST helper] Chạy recursive hybrid:
      - Math backbone: linear trend trên log-price (fit trên df_hist ban đầu)
      - XGB: dự đoán residual (resid_ret)
      - future_ret_final = math_ret_forecast + resid_pred

    Trả về:
      - raw_base_prices: giá future nếu chỉ dùng hybrid
      - raw_base_rets:   future_ret_final (log-return) mỗi bước
    """
    df_state = df_hist.sort_values("time").reset_index(drop=True).copy()
    df_state["close"] = df_state["close"].astype(float)
    df_state["close_log"] = np.log(df_state["close"] + 1e-8)

    # Fit math backbone (trend) trên df_hist ban đầu
    N_hist = len(df_state)
    time_idx_hist = np.arange(N_hist).reshape(-1, 1)
    y_log_hist = df_state["close_log"].values.reshape(-1, 1)
    lr_trend = LinearRegression()
    lr_trend.fit(time_idx_hist, y_log_hist)

    # Extend trend cho tương lai
    total_len = N_hist + total_days
    time_idx_full = np.arange(total_len).reshape(-1, 1)
    trend_log_full = lr_trend.predict(time_idx_full).flatten()

    # Precompute math_ret_forecast cho từng bước
    math_rets_forecast = np.zeros(total_days, dtype=float)
    for k in range(total_days):
        base_idx = N_hist - 1 + k
        if base_idx + 1 < len(trend_log_full):
            math_rets_forecast[k] = trend_log_full[base_idx + 1] - trend_log_full[base_idx]
        else:
            math_rets_forecast[k] = math_rets_forecast[k - 1] if k > 0 else 0.0

    raw_prices: List[float] = []
    raw_rets: List[float] = []

    for step_idx in range(total_days):
        last_close = df_state["close"].iloc[-1]
        last_time = df_state["time"].iloc[-1]

        # tạo row mới với close = last_close (sẽ bị update lại ở cuối vòng)
        new_row = {"time": last_time + BDay(1), "close": last_close}
        if "volume" in df_state.columns:
            new_row["volume"] = df_state["volume"].iloc[-1]
        if all(c in df_state.columns for c in ["open", "high", "low"]):
            new_row["open"] = last_close
            new_row["high"] = last_close
            new_row["low"] = last_close

        df_state = pd.concat([df_state, pd.DataFrame([new_row])], ignore_index=True)
        df_state["close"] = df_state["close"].astype(float)
        df_state["close_log"] = np.log(df_state["close"] + 1e-8)

        # FE lại cho toàn bộ state (bao gồm ngày mới)
        df_state_feat = add_stl_ohlcv_features(df_state, stl_period=stl_period)
        last_row = df_state_feat.iloc[-1]
        feat_vals = []
        for col in feature_cols:
            v = last_row.get(col, np.nan)
            if pd.isna(v):
                v = 0.0
            feat_vals.append(v)

        X_last = np.array(feat_vals, dtype=np.float32).reshape(1, -1)
        X_last_s = scaler_X.transform(X_last)

        # XGB dự đoán residual
        resid_pred = float(xgb.predict(X_last_s)[0])

        # Math drift + residual = hybrid return
        math_ret = float(math_rets_forecast[step_idx])
        final_ret = math_ret + resid_pred

        # Cập nhật giá
        last_log = df_state["close_log"].iloc[-2]
        next_log = last_log + final_ret
        next_price = float(np.exp(next_log))

        last_idx = df_state.index[-1]
        df_state.at[last_idx, "close"] = next_price
        df_state.at[last_idx, "close_log"] = np.log(next_price + 1e-8)
        if all(c in df_state.columns for c in ["open", "high", "low"]):
            df_state.at[last_idx, "open"] = next_price
            df_state.at[last_idx, "high"] = next_price
            df_state.at[last_idx, "low"] = next_price

        raw_prices.append(next_price)
        raw_rets.append(final_ret)

    return np.array(raw_prices, dtype=float), np.array(raw_rets, dtype=float)

# %% [markdown]
# ##**2.6. REGIME DETECTOR + PRICING LAYER  [CV-EVAL + FORECAST]**

# %%
def detect_regime(hist_close: np.ndarray,
                  df_feat_hist: pd.DataFrame) -> str:
    """
    [FORECAST + CV] Phân loại chế độ thị trường:
      - BULL: giá trên MA120 và vol_20 thấp hơn vol dài hạn
      - BEAR: giá dưới MA120 và vol_20 cao hơn vol dài hạn
      - SIDEWAYS: còn lại
    """
    price_series = pd.Series(hist_close.astype(float))
    if len(price_series) >= 120:
        ma_long = price_series.rolling(120).mean().iloc[-1]
    else:
        ma_long = price_series.mean()

    price_last = price_series.iloc[-1]
    price_pos = price_last / (ma_long + 1e-8) - 1.0  # % chênh lệch so với MA120

    ret_1d = df_feat_hist["ret_1d"].dropna()
    if len(ret_1d) < 30:
        return "SIDEWAYS"

    vol_20 = ret_1d.rolling(20).std().iloc[-1]
    vol_all = ret_1d.std()
    vol_ratio = vol_20 / (vol_all + 1e-8)

    if price_pos < -0.05 and vol_ratio > 1.2:
        regime = "BEAR"
    elif price_pos > 0.05 and vol_ratio < 0.8:
        regime = "BULL"
    else:
        regime = "SIDEWAYS"

    # print(f"[REGIME] last_price={price_last:.2f}, MA120={ma_long:.2f}, "
    #       f"price_pos={price_pos*100:.2f}%, vol_ratio={vol_ratio:.2f} -> {regime}")

    return regime


def apply_pricing_on_raw_path(
    hist_close: np.ndarray,
    df_feat_hist: pd.DataFrame,
    raw_rets: np.ndarray,
    pricing: PricingParams,
) -> np.ndarray:
    """
    [FORECAST + CV] Áp pricing-layer lên chuỗi raw_rets hybrid:
      - Clip ret theo quantile trên |ret_1d| history, scale theo vol & regime
      - Damping bằng half-life, scale theo regime
      - Mean-revert quanh fair_level (MA60) với gating theo trend dài hạn & regime
    """
    total_days = len(raw_rets)

    # Fair value level ~ MA60
    FAIR_MA_LEN = 60
    if len(hist_close) >= FAIR_MA_LEN:
        fair_level = float(hist_close[-FAIR_MA_LEN:].mean())
    else:
        fair_level = float(hist_close.mean())

    # Clip theo quantile của |ret_1d|
    hist_abs_ret = df_feat_hist["ret_1d"].dropna().abs()
    if len(hist_abs_ret) == 0:
        base_ret_clip = 0.05
    else:
        base_ret_clip = float(hist_abs_ret.quantile(pricing.ret_clip_quantile))

    # Vol ratio
    ret_1d = df_feat_hist["ret_1d"].dropna()
    if len(ret_1d) >= 30:
        vol_20 = ret_1d.rolling(20).std().iloc[-1]
        vol_all = ret_1d.std()
        vol_ratio = vol_20 / (vol_all + 1e-8)
    else:
        vol_ratio = 1.0

    # Regime
    regime = detect_regime(hist_close, df_feat_hist)

    # Regime-based scaling
    if regime == "BULL":
        clip_scale_regime = 1.2
        mr_alpha_scale_regime = 0.7
        damp_scale_regime = 0.85
        up_mult_scale_regime = 1.05
        down_mult_scale_regime = 1.0
    elif regime == "BEAR":
        clip_scale_regime = 0.95
        mr_alpha_scale_regime = 1.25
        damp_scale_regime = 1.15
        up_mult_scale_regime = 0.95
        down_mult_scale_regime = 0.95
    else:  # SIDEWAYS
        clip_scale_regime = 1.0
        mr_alpha_scale_regime = 1.0
        damp_scale_regime = 1.0
        up_mult_scale_regime = 1.0
        down_mult_scale_regime = 1.0

    clip_scale_vol = float(np.clip(vol_ratio, 0.8, 1.2))

    ret_clip = base_ret_clip * clip_scale_regime * clip_scale_vol
    ret_clip = float(np.clip(ret_clip, 0.01, 0.15))

    lambda_damp = np.log(2.0) / float(max(int(pricing.half_life_days * damp_scale_regime), 1))

    alpha_base = pricing.mean_revert_alpha * mr_alpha_scale_regime
    fair_up_mult = pricing.fair_up_mult * up_mult_scale_regime
    fair_down_mult = pricing.fair_down_mult * down_mult_scale_regime

    prices = np.empty(total_days, dtype=float)
    full_history = list(hist_close.astype(float))

    for step_idx in range(total_days):
        raw_ret = float(raw_rets[step_idx])

        # 1) Clip return
        pred_ret = np.clip(raw_ret, -ret_clip, ret_clip)

        # 2) Damping theo half-life
        scale = np.exp(-lambda_damp * step_idx)
        pred_ret *= scale

        # 3) Convert sang price
        last_price = full_history[-1]
        next_price = float(last_price * np.exp(pred_ret))

        # 4) Trend-based gating for mean-revert
        lookback = pricing.trend_lookback
        if len(full_history) > lookback:
            past_price = full_history[-lookback]
            current_price = full_history[-1]
            trend_ret = (current_price - past_price) / max(past_price, 1e-6)
        else:
            trend_ret = 0.0

        is_strong_uptrend = trend_ret > pricing.trend_ret_thresh
        is_strong_downtrend = trend_ret < -pricing.trend_ret_thresh

        # 5) Mean-revert quanh fair_level
        if step_idx >= pricing.mean_revert_start:
            upper = fair_level * fair_up_mult
            lower = fair_level * fair_down_mult

            if (next_price > upper) and (not is_strong_uptrend):
                alpha_up = alpha_base * (0.7 if regime == "BULL" else 1.0)
                next_price = (1 - alpha_up) * next_price + alpha_up * upper
            elif next_price < lower:
                if regime == "BEAR" and is_strong_downtrend:
                    alpha_down = alpha_base * 0.7
                else:
                    alpha_down = alpha_base
                next_price = (1 - alpha_down) * next_price + alpha_down * lower

        prices[step_idx] = next_price
        full_history.append(next_price)

    return prices

# %% [markdown]
# ##**2.7. CV CUTOFF BUILDER  [CV-EVAL]**

# %%
def build_cv_cutoffs(
    df_train: pd.DataFrame,
    start_year: int,
    end_year: int,
    horizon_days: int,
) -> List[pd.Timestamp]:
    """
    [CV-EVAL] Chọn cutoff: cuối các tháng [3, 6, 9, 12] mỗi năm trong [start_year, end_year],
    nhưng đảm bảo cutoff + horizon_days BDay vẫn nằm trong FPT_train.
    """
    df = df_train.sort_values("time").reset_index(drop=True)
    last_date = df["time"].max()
    cutoffs: List[pd.Timestamp] = []

    CUTOFF_MONTHS = [3, 6, 9, 12]

    for year in range(start_year, end_year + 1):
        df_year = df[df["time"].dt.year == year]
        if df_year.empty:
            continue
        for m in CUTOFF_MONTHS:
            df_month = df_year[df_year["time"].dt.month == m]
            if df_month.empty:
                continue
            candidate = df_month["time"].max()
            if candidate + BDay(horizon_days) <= last_date:
                cutoffs.append(candidate)

    cutoffs = sorted(list(set(cutoffs)))
    print("[CV] Cutoffs (multi-month, trong FPT_train):")
    for c in cutoffs:
        print(" -", c.date())
    return cutoffs

# %% [markdown]
# ##**2.8. BUILD CUTOFF MODELS  [TRAIN (mini-model) cho CV-EVAL]**

# %%
def build_cutoff_models(
    df_train: pd.DataFrame,
    cv_cutoffs: List[pd.Timestamp],
    stl_period: int,
    horizon: int,
) -> List[CutoffModel]:
    """
    [TRAIN cho CV] – với mỗi cutoff:
      - Train một XGB residual + scaler trên history <= cutoff
      - Sinh raw hybrid path 100 ngày sau cutoff để dùng trong CV Pricing
    """
    models: List[CutoffModel] = []
    for cutoff in cv_cutoffs:
        df_hist_cut = df_train[df_train["time"] <= cutoff].copy().reset_index(drop=True)
        if len(df_hist_cut) < 250:
            print(f"[CV] Skip cutoff {cutoff.date()} (not enough OHLCV history)")
            continue

        print(f"\n[CV] === Cutoff {cutoff.date()} ===")
        df_feat_cut, df_model_cut, feature_cols = build_modeling_df(
            df_hist_cut,
            stl_period=stl_period,
            horizon=horizon,
        )

        # [TRAIN] mini XGB cho cutoff này
        xgb, scaler_X, _, _ = train_xgb_on_dfmodel(df_model_cut, feature_cols)

        # [FORECAST helper] tạo raw hybrid path cho CV_HORIZON
        raw_prices_cv, raw_rets_cv = build_raw_base_path_hybrid(
            df_hist=df_hist_cut,
            xgb=xgb,
            scaler_X=scaler_X,
            feature_cols=feature_cols,
            total_days=CV_HORIZON,
            stl_period=stl_period,
        )

        models.append(
            CutoffModel(
                cutoff_time=cutoff,
                xgb=xgb,
                scaler_X=scaler_X,
                feature_cols=feature_cols,
                df_hist=df_hist_cut,
                df_feat=df_feat_cut,
                raw_base_prices_cv=raw_prices_cv,
                raw_base_rets_cv=raw_rets_cv,
            )
        )

    return models

# %% [markdown]
# ##**2.9. RANDOM SEARCH PRICING  [CV-EVAL chính]**

# %%
def sample_pricing_params() -> PricingParams:
    """Sample ngẫu nhiên 1 bộ tham số Pricing-layer."""
    return PricingParams(
        ret_clip_quantile=random.uniform(0.95, 0.995),
        half_life_days=random.randint(40, 120),
        mean_revert_alpha=random.uniform(0.02, 0.10),
        mean_revert_start=random.randint(25, 65),
        fair_up_mult=random.uniform(1.25, 1.60),
        fair_down_mult=random.uniform(0.65, 0.90),
        trend_lookback=random.randint(25, 60),
        trend_ret_thresh=random.uniform(0.08, 0.25),
    )

def cv_mse_for_pricing(
    models: List[CutoffModel],
    df_train: pd.DataFrame,
    horizon: int,
    pricing: PricingParams,
) -> float:
    """
    [CV-EVAL] Tính metric của pricing-layer trên nhiều cutoff:
      - Với mỗi cutoff:
          + true close sau cutoff
          + giá predicted khi áp pricing lên raw_base_rets_cv
      - Metric:
          M = 0.5 * MSE_50 + 0.5 * MSE_100
    """
    mses = []
    for cm in models:
        df_future = df_train[df_train["time"] > cm.cutoff_time].copy().reset_index(drop=True)
        if df_future.empty:
            continue
        close_true = df_future["close"].values.astype(float)

        n_eval = min(horizon, len(close_true))
        if n_eval <= 5:
            continue

        hist_close = cm.df_hist["close"].values.astype(float)
        priced = apply_pricing_on_raw_path(
            hist_close=hist_close,
            df_feat_hist=cm.df_feat,
            raw_rets=cm.raw_base_rets_cv[:n_eval],
            pricing=pricing,
        )

        # 50 days metric
        n50 = min(50, n_eval)
        mse_50 = mean_squared_error(close_true[:n50], priced[:n50])

        # full horizon metric
        mse_h = mean_squared_error(close_true[:n_eval], priced[:n_eval])

        metric = 0.5 * mse_50 + 0.5 * mse_h
        mses.append(metric)

    if not mses:
        return np.inf

    return float(np.mean(mses))


def random_search_pricing(
    cutoff_models: List[CutoffModel],
    df_train: pd.DataFrame,
    horizon: int,
    n_trials: int,
) -> PricingParams:
    """
    [CV-EVAL] Random search trên không gian PricingParams
    để tìm bộ có metric trung bình tốt nhất trên các cutoff.
    """
    best_params: Optional[PricingParams] = None
    best_score = np.inf

    for t in range(1, n_trials + 1):
        params = sample_pricing_params()
        score = cv_mse_for_pricing(cutoff_models, df_train, horizon, params)
        print(f"[RS] Trial {t}/{n_trials} -> METRIC={score:.4f}, params={params}")
        if score < best_score:
            best_score = score
            best_params = params

    print("\n=== BEST PRICING PARAMS (Hybrid + Regime, Pure FPT) ===")
    print(best_params)
    print("CV METRIC (0.5*MSE_50 + 0.5*MSE_100):", best_score)
    return best_params

# %%
def cv_mse_for_pricing(
    models: List[CutoffModel],
    df_train: pd.DataFrame,
    horizon: int,
    pricing: PricingParams,
) -> float:
    """
    Tính metric của pricing-layer trên nhiều cutoff:
      - Với mỗi cutoff:
          + true close sau cutoff
          + giá predicted khi áp pricing lên raw_base_rets_cv
      - Metric:
          M = 0.5 * MSE_50 + 0.5 * MSE_100
    """
    mses = []
    for cm in models:
        df_future = df_train[df_train["time"] > cm.cutoff_time].copy().reset_index(drop=True)
        if df_future.empty:
            continue
        close_true = df_future["close"].values.astype(float)

        n_eval = min(horizon, len(close_true))
        if n_eval <= 5:
            continue

        hist_close = cm.df_hist["close"].values.astype(float)
        priced = apply_pricing_on_raw_path(
            hist_close=hist_close,
            df_feat_hist=cm.df_feat,
            raw_rets=cm.raw_base_rets_cv[:n_eval],
            pricing=pricing,
        )

        # 50 days metric
        n50 = min(50, n_eval)
        mse_50 = mean_squared_error(close_true[:n50], priced[:n50])

        # full horizon metric
        mse_h = mean_squared_error(close_true[:n_eval], priced[:n_eval])

        metric = 0.5 * mse_50 + 0.5 * mse_h
        mses.append(metric)

    if not mses:
        return np.inf

    return float(np.mean(mses))


def random_search_pricing(
    cutoff_models: List[CutoffModel],
    df_train: pd.DataFrame,
    horizon: int,
    n_trials: int,
) -> PricingParams:
    best_params: Optional[PricingParams] = None
    best_score = np.inf

    for t in range(1, n_trials + 1):
        params = sample_pricing_params()
        score = cv_mse_for_pricing(cutoff_models, df_train, horizon, params)
        print(f"[RS] Trial {t}/{n_trials} -> METRIC={score:.4f}, params={params}")
        if score < best_score:
            best_score = score
            best_params = params

    print("\n=== BEST PRICING PARAMS v5.2 Option 2 (Hybrid + Regime, Pure FPT) ===")
    print(best_params)
    print("CV METRIC (0.5*MSE_50 + 0.5*MSE_100):", best_score)
    return best_params

# %% [markdown]
# ##**2.10. UNCERTAINTY BAND  [FORECAST]**

# %%
def build_uncertainty_band(
    base_path: np.ndarray,
    resid_std: float,
    resid_mean: float = 0.0,
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    [FORECAST] analytic band ~ random walk với sigma = resid_std.
    Dùng cho Risk Expert.
    """
    H = len(base_path)
    steps = np.arange(1, H + 1, dtype=float)
    base_log = np.log(base_path + 1e-8)

    sigma_h = resid_std * np.sqrt(steps)
    lower_log = base_log - UNCERT_Z * sigma_h
    upper_log = base_log + UNCERT_Z * sigma_h
    center_log = base_log + resid_mean * steps * 0.0  # bỏ drift residual

    lower = np.exp(lower_log)
    upper = np.exp(upper_log)
    center = np.exp(center_log)

    return center, lower, upper

# %% [markdown]
# ##**2.11. TRAIN FINAL BASE MODEL  [TRAIN]**

# %%
def train_final_base_model(
    df_train: pd.DataFrame,
    stl_period: int,
    horizon: int,
) -> FinalBaseModel:
    """
    [TRAIN] Train XGB residual cuối cùng trên toàn bộ FPT_train.
    """
    df_feat, df_model, feature_cols = build_modeling_df(
        df_train,
        stl_period=stl_period,
        horizon=horizon,
    )

    xgb, scaler_X, resid_std, resid_mean = train_xgb_on_dfmodel(df_model, feature_cols)

    return FinalBaseModel(
        xgb=xgb,
        scaler_X=scaler_X,
        feature_cols=feature_cols,
        df_train=df_train.sort_values("time").reset_index(drop=True),
        df_feat=df_feat,
        train_end_date=df_train["time"].max(),
        resid_std=resid_std,
        resid_mean=resid_mean,
    )

# %% [markdown]
# ##**2.12. MAIN  [gồm TRAIN + CV-EVAL + FORECAST + OUTPUT]**

# %%
def main():
    # --------------------------------------------------------
    # (1) LOAD RAW
    # --------------------------------------------------------
    df_train_raw = pd.read_csv(FPT_TRAIN_PATH)

    # --------------------------------------------------------
    # (1a) PREPROCESS (clean time-axis + sanity OHLCV)
    # --------------------------------------------------------
    df_train = preprocess_fpt_train(df_train_raw)

    # --------------------------------------------------------
    # (1b) OPTIONAL: FORCE CUT TRAIN END DATE
    # --------------------------------------------------------
    if FORCE_TRAIN_END_DATE is not None:
        cutoff_dt = pd.to_datetime(FORCE_TRAIN_END_DATE)
        orig_min = df_train["time"].min()
        orig_max = df_train["time"].max()
        df_train = df_train[df_train["time"] <= cutoff_dt].copy().reset_index(drop=True)
        print(f"[TRICK] FORCE_TRAIN_END_DATE = {cutoff_dt.date()} "
              f"(original train range: {orig_min.date()} -> {orig_max.date()})")
    else:
        print("[TRICK] FORCE_TRAIN_END_DATE = None (train tới ngày cuối trong FPT_train).")

    print("FPT_train (pure, after cutoff):", df_train["time"].min(),
          "->", df_train["time"].max(), ",", df_train.shape)
    train_end_date = df_train["time"].max()

    # --------------------------------------------------------
    # (2) BUILD CV CUTOFFS + CUTOFF MODELS  [TRAIN + CV-EVAL]
    # --------------------------------------------------------
    cv_cutoffs = build_cv_cutoffs(df_train, CV_START_YEAR, CV_END_YEAR, CV_HORIZON)

    if not cv_cutoffs:
        print("[CV] Không tìm được cutoff phù hợp, dùng default pricing params.")
        pricing_best = PricingParams(
            ret_clip_quantile=0.99,
            half_life_days=60,
            mean_revert_alpha=0.06,
            mean_revert_start=40,
            fair_up_mult=1.4,
            fair_down_mult=0.75,
            trend_lookback=30,
            trend_ret_thresh=0.18,
        )
    else:
        cutoff_models = build_cutoff_models(
            df_train=df_train,
            cv_cutoffs=cv_cutoffs,
            stl_period=STL_PERIOD,
            horizon=HORIZON,
        )
        if not cutoff_models:
            print("[CV] Không train được cutoff model nào, dùng default pricing params.")
            pricing_best = PricingParams(
                ret_clip_quantile=0.99,
                half_life_days=60,
                mean_revert_alpha=0.06,
                mean_revert_start=40,
                fair_up_mult=1.4,
                fair_down_mult=0.75,
                trend_lookback=30,
                trend_ret_thresh=0.18,
            )
        else:
            pricing_best = random_search_pricing(
                cutoff_models=cutoff_models,
                df_train=df_train,
                horizon=CV_HORIZON,
                n_trials=N_RANDOM_TRIALS,
            )

    # --------------------------------------------------------
    # (3) TRAIN FINAL BASE MODEL  [TRAIN]
    # --------------------------------------------------------
    final_base = train_final_base_model(
        df_train=df_train,
        stl_period=STL_PERIOD,
        horizon=HORIZON,
    )

    # --------------------------------------------------------
    # (4) FORECAST 100 NGÀY  [FORECAST]
    # --------------------------------------------------------
    raw_base_prices_final, raw_rets_final = build_raw_base_path_hybrid(
        df_hist=final_base.df_train,
        xgb=final_base.xgb,
        scaler_X=final_base.scaler_X,
        feature_cols=final_base.feature_cols,
        total_days=TOTAL_PREDICT_DAYS,
        stl_period=STL_PERIOD,
    )

    hist_close_full = final_base.df_train["close"].values.astype(float)

    base_path = apply_pricing_on_raw_path(
        hist_close=hist_close_full,
        df_feat_hist=final_base.df_feat,
        raw_rets=raw_rets_final,
        pricing=pricing_best,
    )

    df_trend = final_base.df_train.sort_values("time").reset_index(drop=True)
    df_trend["time_idx"] = np.arange(len(df_trend))
    lr = LinearRegression()
    lr.fit(df_trend[["time_idx"]].values, df_trend["close"].values.astype(float))
    last_idx = int(df_trend["time_idx"].iloc[-1])
    future_idx = np.arange(last_idx + 1,
                           last_idx + 1 + TOTAL_PREDICT_DAYS).reshape(-1, 1)
    trend_price = lr.predict(future_idx)

    uncert_center_ana, uncert_lower_ana, uncert_upper_ana = build_uncertainty_band(
        base_path,
        final_base.resid_std,
        final_base.resid_mean,
    )

    central_det = 0.7 * base_path + 0.25 * trend_price + 0.05 * uncert_center_ana
    bull = np.maximum(base_path, trend_price)
    bear = np.minimum(base_path, trend_price)

    start_date = train_end_date + BDay(1)
    future_dates = pd.bdate_range(start=start_date, periods=TOTAL_PREDICT_DAYS)

    # --------------------------------------------------------
    # (5) PLOT & SAVE OUTPUT  [OUTPUT]
    # --------------------------------------------------------
    plt.figure(figsize=(14, 7))
    plt.plot(df_train["time"], df_train["close"],
             label="FPT Train", alpha=0.4)

    plt.axvline(train_end_date, color="gray",
                linestyle="--", label="Train End")
    plt.plot(future_dates, base_path,
             label="BASE (Hybrid + Pricing)", linestyle=":")
    plt.plot(future_dates, trend_price,
             label="TREND (Linear)", linestyle="--")
    plt.plot(future_dates, central_det,
             label="CENTRAL_DET", linewidth=2)
    plt.fill_between(future_dates, uncert_lower_ana, uncert_upper_ana,
                     alpha=0.10, label="UNCERT analytic")

    plt.title("FPT 100-day Forecast (Hybrid + Pricing)")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.grid(alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

    out = pd.DataFrame({
        "time": future_dates,
        "base": base_path,
        "trend": trend_price,
        "uncert_center_ana": uncert_center_ana,
        "uncert_lower_ana": uncert_lower_ana,
        "uncert_upper_ana": uncert_upper_ana,
        "central_det": central_det,
        "bull": bull,
        "bear": bear,
    })
    out.to_csv("FPT_forecast.csv", index=False)
    print("Saved FPT_forecast.csv ✅")

    sub_days = min(TOTAL_PREDICT_DAYS, TOTAL_PREDICT_DAYS)
    submission = pd.DataFrame({
        "id": np.arange(1, sub_days + 1),
        "close": central_det[:sub_days],
    })
    submission.to_csv("submission.csv", index=False)
    print("Saved submission.csv ✅")

# %% [markdown]
# ## **Run Code**

# %%
if __name__ == "__main__":
    main()
# Out:
# [PREPROCESS] Done. Range: 2020-08-03 -> 2025-03-10, shape=(1149, 7)
# [TRICK] FORCE_TRAIN_END_DATE = None (train tới ngày cuối trong FPT_train).
# FPT_train (pure, after cutoff): 2020-08-03 00:00:00 -> 2025-03-10 00:00:00 , (1149, 7)
# [CV] Cutoffs (multi-month, trong FPT_train):
#  - 2020-09-30
#  - 2020-12-31
#  - 2021-03-31
#  - 2021-06-30
#  - 2021-09-30
#  - 2021-12-31
#  - 2022-03-31
#  - 2022-06-30
#  - 2022-09-30
#  - 2022-12-30
#  - 2023-03-31
#  - 2023-06-30
#  - 2023-09-29
#  - 2023-12-29
#  - 2024-03-29
#  - 2024-06-28
#  - 2024-09-30
# [CV] Skip cutoff 2020-09-30 (not enough OHLCV history)
# [CV] Skip cutoff 2020-12-31 (not enough OHLCV history)
# [CV] Skip cutoff 2021-03-31 (not enough OHLCV history)
# [CV] Skip cutoff 2021-06-30 (not enough OHLCV history)
#
# [CV] === Cutoff 2021-09-30 ===
# Modeling DF shape: (271, 60)
# === XGB RESIDUAL MODEL (271 samples) ===
# Train (resid) -> MSE: 3.967305e-06 | MAE: 1.449321e-03
# Val (resid) -> MSE: 4.854814e-04 | MAE: 1.807061e-02
# Test (resid) -> MSE: 1.479850e-04 | MAE: 1.049716e-02
# [RESID] std=8.178908e-03, mean=4.164168e-04
#
# [CV] === Cutoff 2021-12-31 ===
# Modeling DF shape: (337, 60)
# === XGB RESIDUAL MODEL (337 samples) ===
# Train (resid) -> MSE: 4.702173e-06 | MAE: 1.561026e-03
# Val (resid) -> MSE: 1.472483e-04 | MAE: 9.725678e-03
# Test (resid) -> MSE: 1.798709e-04 | MAE: 1.131234e-02
# [RESID] std=6.039416e-03, mean=-6.246443e-04
#
# [CV] === Cutoff 2022-03-31 ===
# Modeling DF shape: (395, 60)
# === XGB RESIDUAL MODEL (395 samples) ===
# Train (resid) -> MSE: 6.688196e-06 | MAE: 1.892716e-03
# Val (resid) -> MSE: 2.906552e-04 | MAE: 1.392455e-02
# Test (resid) -> MSE: 2.866866e-04 | MAE: 1.181797e-02
# [RESID] std=7.907585e-03, mean=-8.414995e-04
#
# [CV] === Cutoff 2022-06-30 ===
# Modeling DF shape: (457, 60)
# === XGB RESIDUAL MODEL (457 samples) ===
# Train (resid) -> MSE: 9.485005e-06 | MAE: 2.244412e-03
# Val (resid) -> MSE: 5.259576e-04 | MAE: 1.523565e-02
# Test (resid) -> MSE: 1.042832e-03 | MAE: 2.505034e-02
# [RESID] std=1.286374e-02, mean=-6.087734e-04
#
# [CV] === Cutoff 2022-09-30 ===
# Modeling DF shape: (521, 60)
# === XGB RESIDUAL MODEL (521 samples) ===
# Train (resid) -> MSE: 1.300049e-05 | MAE: 2.652088e-03
# Val (resid) -> MSE: 8.870040e-04 | MAE: 2.382580e-02
# Test (resid) -> MSE: 1.357178e-04 | MAE: 8.678353e-03
# [RESID] std=1.060340e-02, mean=-7.074811e-04
#
# [CV] === Cutoff 2022-12-30 ===
# Modeling DF shape: (586, 60)
# === XGB RESIDUAL MODEL (586 samples) ===
# Train (resid) -> MSE: 1.979899e-05 | MAE: 3.300798e-03
# Val (resid) -> MSE: 2.244478e-04 | MAE: 1.117738e-02
# Test (resid) -> MSE: 4.055299e-04 | MAE: 1.424230e-02
# [RESID] std=8.903492e-03, mean=3.210320e-04
#
# [CV] === Cutoff 2023-03-31 ===
# Modeling DF shape: (645, 60)
# === XGB RESIDUAL MODEL (645 samples) ===
# Train (resid) -> MSE: 2.108038e-05 | MAE: 3.412790e-03
# Val (resid) -> MSE: 4.652300e-04 | MAE: 1.553529e-02
# Test (resid) -> MSE: 1.081785e-04 | MAE: 7.748649e-03
# [RESID] std=8.604798e-03, mean=2.462326e-05
#
# [CV] === Cutoff 2023-06-30 ===
# Modeling DF shape: (707, 60)
# === XGB RESIDUAL MODEL (707 samples) ===
# Train (resid) -> MSE: 2.878583e-05 | MAE: 3.966379e-03
# Val (resid) -> MSE: 1.723106e-04 | MAE: 9.780602e-03
# Test (resid) -> MSE: 8.433009e-05 | MAE: 7.081895e-03
# [RESID] std=6.952865e-03, mean=7.094073e-04
#
# [CV] === Cutoff 2023-09-29 ===
# Modeling DF shape: (770, 60)
# === XGB RESIDUAL MODEL (770 samples) ===
# Train (resid) -> MSE: 3.387185e-05 | MAE: 4.293860e-03
# Val (resid) -> MSE: 8.295565e-05 | MAE: 7.081323e-03
# Test (resid) -> MSE: 2.751852e-04 | MAE: 1.259634e-02
# [RESID] std=7.936257e-03, mean=9.584990e-05
#
# [CV] === Cutoff 2023-12-29 ===
# Modeling DF shape: (835, 60)
# === XGB RESIDUAL MODEL (835 samples) ===
# Train (resid) -> MSE: 3.391505e-05 | MAE: 4.275066e-03
# Val (resid) -> MSE: 1.503803e-04 | MAE: 9.120038e-03
# Test (resid) -> MSE: 2.896397e-04 | MAE: 1.304620e-02
# [RESID] std=8.426650e-03, mean=-5.422485e-04
#
# [CV] === Cutoff 2024-03-29 ===
# Modeling DF shape: (894, 60)
# === XGB RESIDUAL MODEL (894 samples) ===
# Train (resid) -> MSE: 3.454007e-05 | MAE: 4.293041e-03
# Val (resid) -> MSE: 2.779936e-04 | MAE: 1.296330e-02
# Test (resid) -> MSE: 1.943544e-04 | MAE: 1.068052e-02
# [RESID] std=8.642338e-03, mean=5.086447e-04
#
# [CV] === Cutoff 2024-06-28 ===
# Modeling DF shape: (955, 60)
# === XGB RESIDUAL MODEL (955 samples) ===
# Train (resid) -> MSE: 3.759104e-05 | MAE: 4.528059e-03
# Val (resid) -> MSE: 2.161711e-04 | MAE: 1.080051e-02
# Test (resid) -> MSE: 6.267574e-04 | MAE: 2.005582e-02
# [RESID] std=1.060548e-02, mean=1.490697e-03
#
# [CV] === Cutoff 2024-09-30 ===
# Modeling DF shape: (1019, 60)
# === XGB RESIDUAL MODEL (1019 samples) ===
# Train (resid) -> MSE: 3.912950e-05 | MAE: 4.641505e-03
# Val (resid) -> MSE: 3.014245e-04 | MAE: 1.241119e-02
# Test (resid) -> MSE: 5.660655e-04 | MAE: 1.833456e-02
# [RESID] std=1.072216e-02, mean=1.810560e-03
# [RS] Trial 1/120 -> METRIC=119.2681, params=PricingParams(ret_clip_quantile=0.9660379193043225, half_life_days=45, mean_revert_alpha=0.048190291773183264, mean_revert_start=28, fair_up_mult=1.5901841734771855, fair_down_mult=0.7204752071354191, trend_lookback=60, trend_ret_thresh=0.09099107968797158)
# [RS] Trial 2/120 -> METRIC=134.9074, params=PricingParams(ret_clip_quantile=0.9723657580908833, half_life_days=65, mean_revert_alpha=0.05180782737406302, mean_revert_start=48, fair_up_mult=1.2514071630060661, fair_down_mult=0.8450003500863026, trend_lookback=25, trend_ret_thresh=0.2079858335492149)
# [RS] Trial 3/120 -> METRIC=158.1246, params=PricingParams(ret_clip_quantile=0.9847974473141708, half_life_days=82, mean_revert_alpha=0.02369432428004405, mean_revert_start=56, fair_up_mult=1.317381360686499, fair_down_mult=0.8558395250527728, trend_lookback=35, trend_ret_thresh=0.14849105522294295)
# [RS] Trial 4/120 -> METRIC=150.9074, params=PricingParams(ret_clip_quantile=0.9756320213340506, half_life_days=64, mean_revert_alpha=0.04148426331212844, mean_revert_start=57, fair_up_mult=1.5803251325622214, fair_down_mult=0.7033420416355559, trend_lookback=37, trend_ret_thresh=0.19749165724482154)
# [RS] Trial 5/120 -> METRIC=119.9401, params=PricingParams(ret_clip_quantile=0.9684633761964238, half_life_days=53, mean_revert_alpha=0.09361118249956256, mean_revert_start=58, fair_up_mult=1.5201543707807543, fair_down_mult=0.8566530201327657, trend_lookback=35, trend_ret_thresh=0.22142819061757524)
# [RS] Trial 6/120 -> METRIC=128.3678, params=PricingParams(ret_clip_quantile=0.9641064984516833, half_life_days=62, mean_revert_alpha=0.07599167304960608, mean_revert_start=58, fair_up_mult=1.2770881582733635, fair_down_mult=0.8519994001567897, trend_lookback=27, trend_ret_thresh=0.23472150807164938)
# [RS] Trial 7/120 -> METRIC=193.1299, params=PricingParams(ret_clip_quantile=0.9821608023877739, half_life_days=107, mean_revert_alpha=0.08170203290714662, mean_revert_start=60, fair_up_mult=1.2544207598260018, fair_down_mult=0.6652119395732745, trend_lookback=59, trend_ret_thresh=0.11917206805727037)
# [RS] Trial 8/120 -> METRIC=130.3487, params=PricingParams(ret_clip_quantile=0.9636439942534889, half_life_days=67, mean_revert_alpha=0.07501509204692262, mean_revert_start=27, fair_up_mult=1.2924471200440528, fair_down_mult=0.8615075067339266, trend_lookback=54, trend_ret_thresh=0.2430879130422302)
# [RS] Trial 9/120 -> METRIC=158.9961, params=PricingParams(ret_clip_quantile=0.981227481152418, half_life_days=85, mean_revert_alpha=0.05373198451527575, mean_revert_start=49, fair_up_mult=1.5070557121463386, fair_down_mult=0.820965049935547, trend_lookback=46, trend_ret_thresh=0.12494126666344163)
# [RS] Trial 10/120 -> METRIC=109.1635, params=PricingParams(ret_clip_quantile=0.9794882712410575, half_life_days=41, mean_revert_alpha=0.04639243756166847, mean_revert_start=25, fair_up_mult=1.5609712735673456, fair_down_mult=0.8163301265039666, trend_lookback=32, trend_ret_thresh=0.22871097717972383)
# [RS] Trial 11/120 -> METRIC=123.5623, params=PricingParams(ret_clip_quantile=0.9691216014980767, half_life_days=67, mean_revert_alpha=0.07422692860276774, mean_revert_start=31, fair_up_mult=1.440627235403358, fair_down_mult=0.8997515860439114, trend_lookback=32, trend_ret_thresh=0.1540670808257611)
# [RS] Trial 12/120 -> METRIC=180.7392, params=PricingParams(ret_clip_quantile=0.9689782321451578, half_life_days=98, mean_revert_alpha=0.07957426024686966, mean_revert_start=56, fair_up_mult=1.4827590339281165, fair_down_mult=0.7220847852637802, trend_lookback=56, trend_ret_thresh=0.2080443378649523)
# [RS] Trial 13/120 -> METRIC=164.4096, params=PricingParams(ret_clip_quantile=0.9685055516205298, half_life_days=94, mean_revert_alpha=0.050585085167463864, mean_revert_start=53, fair_up_mult=1.5715299663422593, fair_down_mult=0.8282847922878678, trend_lookback=36, trend_ret_thresh=0.2325792263672356)
# [RS] Trial 14/120 -> METRIC=137.3015, params=PricingParams(ret_clip_quantile=0.9867302272629425, half_life_days=59, mean_revert_alpha=0.09943730030871094, mean_revert_start=41, fair_up_mult=1.423437891234635, fair_down_mult=0.7853469423162843, trend_lookback=36, trend_ret_thresh=0.17386023552849955)
# [RS] Trial 15/120 -> METRIC=165.1633, params=PricingParams(ret_clip_quantile=0.9939733564410748, half_life_days=100, mean_revert_alpha=0.09695565034244664, mean_revert_start=57, fair_up_mult=1.5719364387664985, fair_down_mult=0.8063273571765988, trend_lookback=32, trend_ret_thresh=0.1362446062298004)
# [RS] Trial 16/120 -> METRIC=149.2834, params=PricingParams(ret_clip_quantile=0.9799345688458441, half_life_days=81, mean_revert_alpha=0.06104593199417688, mean_revert_start=61, fair_up_mult=1.3296467979822026, fair_down_mult=0.8479164555781724, trend_lookback=46, trend_ret_thresh=0.15927734419407494)
# [RS] Trial 17/120 -> METRIC=185.6527, params=PricingParams(ret_clip_quantile=0.953105662332694, half_life_days=109, mean_revert_alpha=0.04822872100250472, mean_revert_start=32, fair_up_mult=1.269672290366893, fair_down_mult=0.6904340444751441, trend_lookback=27, trend_ret_thresh=0.1472362193243968)
# [RS] Trial 18/120 -> METRIC=139.8724, params=PricingParams(ret_clip_quantile=0.9632877345567125, half_life_days=59, mean_revert_alpha=0.021199740550137146, mean_revert_start=62, fair_up_mult=1.3322553424866286, fair_down_mult=0.817688309709359, trend_lookback=53, trend_ret_thresh=0.13680583523999548)
# [RS] Trial 19/120 -> METRIC=149.0699, params=PricingParams(ret_clip_quantile=0.9798736520965209, half_life_days=64, mean_revert_alpha=0.062474664351335585, mean_revert_start=26, fair_up_mult=1.2852501038725086, fair_down_mult=0.684549938802143, trend_lookback=54, trend_ret_thresh=0.22071292268703063)
# [RS] Trial 20/120 -> METRIC=133.6778, params=PricingParams(ret_clip_quantile=0.9815496006142691, half_life_days=55, mean_revert_alpha=0.06257714507488603, mean_revert_start=25, fair_up_mult=1.5387843107808403, fair_down_mult=0.7817613561135864, trend_lookback=58, trend_ret_thresh=0.10081503010794948)
# [RS] Trial 21/120 -> METRIC=155.8877, params=PricingParams(ret_clip_quantile=0.9581360387130942, half_life_days=98, mean_revert_alpha=0.05342821578000921, mean_revert_start=28, fair_up_mult=1.4945051531952058, fair_down_mult=0.8740997372570575, trend_lookback=51, trend_ret_thresh=0.14042226786351403)
# [RS] Trial 22/120 -> METRIC=114.6836, params=PricingParams(ret_clip_quantile=0.9946236662423383, half_life_days=43, mean_revert_alpha=0.05214611692904071, mean_revert_start=38, fair_up_mult=1.321545060348976, fair_down_mult=0.7646087015949361, trend_lookback=45, trend_ret_thresh=0.13283716084925362)
# [RS] Trial 23/120 -> METRIC=172.5671, params=PricingParams(ret_clip_quantile=0.9580369468810161, half_life_days=96, mean_revert_alpha=0.028219009277949052, mean_revert_start=42, fair_up_mult=1.4985946784564705, fair_down_mult=0.8275083741368485, trend_lookback=31, trend_ret_thresh=0.12797243983935305)
# [RS] Trial 24/120 -> METRIC=197.5431, params=PricingParams(ret_clip_quantile=0.9940284652106515, half_life_days=118, mean_revert_alpha=0.08646781733366646, mean_revert_start=30, fair_up_mult=1.4914289309498092, fair_down_mult=0.6861384357132878, trend_lookback=45, trend_ret_thresh=0.0838008754585039)
# [RS] Trial 25/120 -> METRIC=190.5938, params=PricingParams(ret_clip_quantile=0.9610920864472718, half_life_days=109, mean_revert_alpha=0.03587037412353582, mean_revert_start=62, fair_up_mult=1.445845199869576, fair_down_mult=0.72436895031085, trend_lookback=44, trend_ret_thresh=0.22661671452379556)
# [RS] Trial 26/120 -> METRIC=189.9505, params=PricingParams(ret_clip_quantile=0.9671405699419012, half_life_days=104, mean_revert_alpha=0.0937075680245836, mean_revert_start=58, fair_up_mult=1.4001605955896697, fair_down_mult=0.6773567671537297, trend_lookback=55, trend_ret_thresh=0.12277596031109668)
# [RS] Trial 27/120 -> METRIC=129.1054, params=PricingParams(ret_clip_quantile=0.9746367130940773, half_life_days=52, mean_revert_alpha=0.02206730900622504, mean_revert_start=58, fair_up_mult=1.3302453908072946, fair_down_mult=0.8179521360006756, trend_lookback=26, trend_ret_thresh=0.17492112314830582)
# [RS] Trial 28/120 -> METRIC=153.0201, params=PricingParams(ret_clip_quantile=0.9797739042383788, half_life_days=72, mean_revert_alpha=0.0334380234937381, mean_revert_start=50, fair_up_mult=1.3041604189839602, fair_down_mult=0.7911347803015005, trend_lookback=26, trend_ret_thresh=0.16380941786847197)
# [RS] Trial 29/120 -> METRIC=147.9899, params=PricingParams(ret_clip_quantile=0.9684037476801354, half_life_days=87, mean_revert_alpha=0.061254307568960706, mean_revert_start=38, fair_up_mult=1.3402922499664611, fair_down_mult=0.862782568764476, trend_lookback=52, trend_ret_thresh=0.17581650367177043)
# [RS] Trial 30/120 -> METRIC=168.3541, params=PricingParams(ret_clip_quantile=0.9916913188262791, half_life_days=81, mean_revert_alpha=0.046006250927048846, mean_revert_start=28, fair_up_mult=1.2925387404521635, fair_down_mult=0.6904777241427003, trend_lookback=56, trend_ret_thresh=0.20404756489263598)
# [RS] Trial 31/120 -> METRIC=180.7756, params=PricingParams(ret_clip_quantile=0.980241951294595, half_life_days=93, mean_revert_alpha=0.0735831650254805, mean_revert_start=53, fair_up_mult=1.403105069205829, fair_down_mult=0.6991393427206649, trend_lookback=59, trend_ret_thresh=0.15201208590018928)
# [RS] Trial 32/120 -> METRIC=194.3333, params=PricingParams(ret_clip_quantile=0.96034716132774, half_life_days=116, mean_revert_alpha=0.04644507749130068, mean_revert_start=27, fair_up_mult=1.579648643419942, fair_down_mult=0.728208539078514, trend_lookback=49, trend_ret_thresh=0.14114794952102386)
# [RS] Trial 33/120 -> METRIC=160.7780, params=PricingParams(ret_clip_quantile=0.9737367960079417, half_life_days=120, mean_revert_alpha=0.06895766054336502, mean_revert_start=48, fair_up_mult=1.3351531050954795, fair_down_mult=0.8492824403363988, trend_lookback=27, trend_ret_thresh=0.22285794348394733)
# [RS] Trial 34/120 -> METRIC=115.9635, params=PricingParams(ret_clip_quantile=0.9768711484994519, half_life_days=48, mean_revert_alpha=0.04751077462370114, mean_revert_start=37, fair_up_mult=1.2926715734121679, fair_down_mult=0.8593823774927236, trend_lookback=25, trend_ret_thresh=0.10422116051836569)
# [RS] Trial 35/120 -> METRIC=141.3516, params=PricingParams(ret_clip_quantile=0.9683405263260576, half_life_days=68, mean_revert_alpha=0.08748515760904899, mean_revert_start=64, fair_up_mult=1.3356548718257995, fair_down_mult=0.8094815433025049, trend_lookback=38, trend_ret_thresh=0.1513042071003934)
# [RS] Trial 36/120 -> METRIC=121.2691, params=PricingParams(ret_clip_quantile=0.9666735864162277, half_life_days=51, mean_revert_alpha=0.059251182574118294, mean_revert_start=25, fair_up_mult=1.3942212536483167, fair_down_mult=0.8464284484301482, trend_lookback=60, trend_ret_thresh=0.16547826174821662)
# [RS] Trial 37/120 -> METRIC=153.2142, params=PricingParams(ret_clip_quantile=0.9941259694575098, half_life_days=66, mean_revert_alpha=0.052894826349120294, mean_revert_start=33, fair_up_mult=1.4835166018069106, fair_down_mult=0.7181670713596684, trend_lookback=45, trend_ret_thresh=0.22453760375152715)
# [RS] Trial 38/120 -> METRIC=157.2105, params=PricingParams(ret_clip_quantile=0.9546929976607647, half_life_days=76, mean_revert_alpha=0.09682885476532543, mean_revert_start=37, fair_up_mult=1.4745850762738388, fair_down_mult=0.7643052163244899, trend_lookback=58, trend_ret_thresh=0.09091067443244132)
# [RS] Trial 39/120 -> METRIC=148.1646, params=PricingParams(ret_clip_quantile=0.9806840282363025, half_life_days=67, mean_revert_alpha=0.030912052862015732, mean_revert_start=29, fair_up_mult=1.4142767758246537, fair_down_mult=0.8070161596111307, trend_lookback=26, trend_ret_thresh=0.1689258886971264)
# [RS] Trial 40/120 -> METRIC=144.8858, params=PricingParams(ret_clip_quantile=0.9869798270152752, half_life_days=60, mean_revert_alpha=0.061055153889438676, mean_revert_start=37, fair_up_mult=1.4703062898127646, fair_down_mult=0.7243101217281439, trend_lookback=50, trend_ret_thresh=0.1467304732375656)
# [RS] Trial 41/120 -> METRIC=142.2697, params=PricingParams(ret_clip_quantile=0.9596252742331086, half_life_days=58, mean_revert_alpha=0.07772668369901539, mean_revert_start=28, fair_up_mult=1.480169029875171, fair_down_mult=0.674668487992665, trend_lookback=31, trend_ret_thresh=0.11077709480117741)
# [RS] Trial 42/120 -> METRIC=134.2765, params=PricingParams(ret_clip_quantile=0.9910938008716891, half_life_days=53, mean_revert_alpha=0.07647768125165065, mean_revert_start=56, fair_up_mult=1.5213948127555907, fair_down_mult=0.6672752796613441, trend_lookback=53, trend_ret_thresh=0.08792546475017463)
# [RS] Trial 43/120 -> METRIC=141.5596, params=PricingParams(ret_clip_quantile=0.9506916679161972, half_life_days=59, mean_revert_alpha=0.08867010227479141, mean_revert_start=44, fair_up_mult=1.3555215994504557, fair_down_mult=0.7367546885745291, trend_lookback=54, trend_ret_thresh=0.18478665613046868)
# [RS] Trial 44/120 -> METRIC=156.2871, params=PricingParams(ret_clip_quantile=0.9547356374201637, half_life_days=70, mean_revert_alpha=0.07315324621068028, mean_revert_start=33, fair_up_mult=1.2849139846273445, fair_down_mult=0.7289314080622292, trend_lookback=51, trend_ret_thresh=0.12410619090487349)
# [RS] Trial 45/120 -> METRIC=196.0150, params=PricingParams(ret_clip_quantile=0.9725591046214439, half_life_days=115, mean_revert_alpha=0.09342519857449948, mean_revert_start=65, fair_up_mult=1.3167492768101086, fair_down_mult=0.6761392336128115, trend_lookback=48, trend_ret_thresh=0.14396310910350701)
# [RS] Trial 46/120 -> METRIC=146.4507, params=PricingParams(ret_clip_quantile=0.9763533626645877, half_life_days=62, mean_revert_alpha=0.034519547511009004, mean_revert_start=32, fair_up_mult=1.4905307797608838, fair_down_mult=0.7504913062917751, trend_lookback=29, trend_ret_thresh=0.2494125850303182)
# [RS] Trial 47/120 -> METRIC=140.7651, params=PricingParams(ret_clip_quantile=0.9702427807964871, half_life_days=104, mean_revert_alpha=0.09128100764257482, mean_revert_start=41, fair_up_mult=1.3438824224551604, fair_down_mult=0.8828511367220673, trend_lookback=33, trend_ret_thresh=0.21907828042284688)
# [RS] Trial 48/120 -> METRIC=149.3118, params=PricingParams(ret_clip_quantile=0.9744910157507476, half_life_days=75, mean_revert_alpha=0.05383795431214908, mean_revert_start=64, fair_up_mult=1.2536036106395936, fair_down_mult=0.8152117772980879, trend_lookback=37, trend_ret_thresh=0.13731670170963936)
# [RS] Trial 49/120 -> METRIC=133.7307, params=PricingParams(ret_clip_quantile=0.9514110207143843, half_life_days=54, mean_revert_alpha=0.07544609315322717, mean_revert_start=44, fair_up_mult=1.287855321095137, fair_down_mult=0.670435482722681, trend_lookback=45, trend_ret_thresh=0.22861441628334095)
# [RS] Trial 50/120 -> METRIC=135.6112, params=PricingParams(ret_clip_quantile=0.9688293593941653, half_life_days=55, mean_revert_alpha=0.036594976827771665, mean_revert_start=33, fair_up_mult=1.2823519889195136, fair_down_mult=0.6841247146150282, trend_lookback=37, trend_ret_thresh=0.2284412502667928)
# [RS] Trial 51/120 -> METRIC=158.3056, params=PricingParams(ret_clip_quantile=0.9603200069316845, half_life_days=96, mean_revert_alpha=0.03895717258015216, mean_revert_start=54, fair_up_mult=1.312523731730887, fair_down_mult=0.8657667350031091, trend_lookback=29, trend_ret_thresh=0.23013250975646143)
# [RS] Trial 52/120 -> METRIC=178.1882, params=PricingParams(ret_clip_quantile=0.9937150517114794, half_life_days=110, mean_revert_alpha=0.0224010135201244, mean_revert_start=31, fair_up_mult=1.251349530838635, fair_down_mult=0.8639079067992762, trend_lookback=38, trend_ret_thresh=0.11714174711939113)
# [RS] Trial 53/120 -> METRIC=172.8651, params=PricingParams(ret_clip_quantile=0.982745755643217, half_life_days=103, mean_revert_alpha=0.09848866591569783, mean_revert_start=61, fair_up_mult=1.4287039540633124, fair_down_mult=0.7643955777505057, trend_lookback=25, trend_ret_thresh=0.23480576918418217)
# [RS] Trial 54/120 -> METRIC=166.2855, params=PricingParams(ret_clip_quantile=0.9739101980391266, half_life_days=78, mean_revert_alpha=0.027124422287950062, mean_revert_start=60, fair_up_mult=1.3821259487071291, fair_down_mult=0.7259206164753096, trend_lookback=41, trend_ret_thresh=0.2399295942266419)
# [RS] Trial 55/120 -> METRIC=168.0559, params=PricingParams(ret_clip_quantile=0.9752733331272935, half_life_days=82, mean_revert_alpha=0.054775201158778486, mean_revert_start=34, fair_up_mult=1.3759566117684228, fair_down_mult=0.7170158157535658, trend_lookback=25, trend_ret_thresh=0.15231262438892673)
# [RS] Trial 56/120 -> METRIC=185.6978, params=PricingParams(ret_clip_quantile=0.9659129689405773, half_life_days=112, mean_revert_alpha=0.07854078622336812, mean_revert_start=44, fair_up_mult=1.3107583230163413, fair_down_mult=0.7160757441665587, trend_lookback=55, trend_ret_thresh=0.2161677752110202)
# [RS] Trial 57/120 -> METRIC=192.6810, params=PricingParams(ret_clip_quantile=0.9948299277322704, half_life_days=104, mean_revert_alpha=0.0609907218316386, mean_revert_start=57, fair_up_mult=1.5949307208734675, fair_down_mult=0.6509751995372139, trend_lookback=53, trend_ret_thresh=0.1531393404511595)
# [RS] Trial 58/120 -> METRIC=185.3259, params=PricingParams(ret_clip_quantile=0.958389972773352, half_life_days=109, mean_revert_alpha=0.05991569164730366, mean_revert_start=59, fair_up_mult=1.3129672602498388, fair_down_mult=0.6990160212206705, trend_lookback=29, trend_ret_thresh=0.23173416963287818)
# [RS] Trial 59/120 -> METRIC=160.7689, params=PricingParams(ret_clip_quantile=0.9756592115072695, half_life_days=74, mean_revert_alpha=0.0569701675387351, mean_revert_start=38, fair_up_mult=1.34914040110275, fair_down_mult=0.6959625841794732, trend_lookback=35, trend_ret_thresh=0.22172571019137305)
# [RS] Trial 60/120 -> METRIC=155.4807, params=PricingParams(ret_clip_quantile=0.9550725245237097, half_life_days=68, mean_revert_alpha=0.08574898039984748, mean_revert_start=28, fair_up_mult=1.5235038568085721, fair_down_mult=0.7013595986765543, trend_lookback=38, trend_ret_thresh=0.23964377373583978)
# [RS] Trial 61/120 -> METRIC=137.1773, params=PricingParams(ret_clip_quantile=0.9784195415186235, half_life_days=108, mean_revert_alpha=0.09875613652266732, mean_revert_start=44, fair_up_mult=1.2815959251538955, fair_down_mult=0.8993253293333143, trend_lookback=49, trend_ret_thresh=0.22658573654156317)
# [RS] Trial 62/120 -> METRIC=149.9228, params=PricingParams(ret_clip_quantile=0.9745282732885715, half_life_days=116, mean_revert_alpha=0.09266223886070823, mean_revert_start=25, fair_up_mult=1.285299599696247, fair_down_mult=0.8601958569830926, trend_lookback=36, trend_ret_thresh=0.1529097954167574)
# [RS] Trial 63/120 -> METRIC=138.1085, params=PricingParams(ret_clip_quantile=0.969974707024912, half_life_days=70, mean_revert_alpha=0.06961543113505497, mean_revert_start=59, fair_up_mult=1.5608375192458388, fair_down_mult=0.8613817186948595, trend_lookback=41, trend_ret_thresh=0.17011175280501334)
# [RS] Trial 64/120 -> METRIC=179.8797, params=PricingParams(ret_clip_quantile=0.9862912475025344, half_life_days=120, mean_revert_alpha=0.03758649311033371, mean_revert_start=28, fair_up_mult=1.3502535720329456, fair_down_mult=0.8182857946290218, trend_lookback=34, trend_ret_thresh=0.16763161406001387)
# [RS] Trial 65/120 -> METRIC=117.0723, params=PricingParams(ret_clip_quantile=0.9840458832361629, half_life_days=44, mean_revert_alpha=0.026053155867935586, mean_revert_start=58, fair_up_mult=1.39075712140354, fair_down_mult=0.7473660938062325, trend_lookback=27, trend_ret_thresh=0.2362744538887523)
# [RS] Trial 66/120 -> METRIC=142.5251, params=PricingParams(ret_clip_quantile=0.9933090253949409, half_life_days=59, mean_revert_alpha=0.06103669763694981, mean_revert_start=34, fair_up_mult=1.2545476709387402, fair_down_mult=0.7382862286053729, trend_lookback=50, trend_ret_thresh=0.09468568609260344)
# [RS] Trial 67/120 -> METRIC=120.7977, params=PricingParams(ret_clip_quantile=0.9568854112338304, half_life_days=46, mean_revert_alpha=0.030576258267592468, mean_revert_start=30, fair_up_mult=1.3373685243628124, fair_down_mult=0.7778078695374668, trend_lookback=59, trend_ret_thresh=0.1581755303289083)
# [RS] Trial 68/120 -> METRIC=119.2681, params=PricingParams(ret_clip_quantile=0.9618178418063803, half_life_days=45, mean_revert_alpha=0.07352327573346877, mean_revert_start=65, fair_up_mult=1.5459517376015786, fair_down_mult=0.7216163565697647, trend_lookback=33, trend_ret_thresh=0.15273607957058621)
# [RS] Trial 69/120 -> METRIC=141.5184, params=PricingParams(ret_clip_quantile=0.9555139619382856, half_life_days=58, mean_revert_alpha=0.07737572412886232, mean_revert_start=62, fair_up_mult=1.4905414800188368, fair_down_mult=0.7259870867007108, trend_lookback=54, trend_ret_thresh=0.2343051641375289)
# [RS] Trial 70/120 -> METRIC=113.8645, params=PricingParams(ret_clip_quantile=0.9931467868394455, half_life_days=45, mean_revert_alpha=0.02222149506466784, mean_revert_start=54, fair_up_mult=1.4082341290473497, fair_down_mult=0.8819396283929561, trend_lookback=57, trend_ret_thresh=0.12343858931543357)
# [RS] Trial 71/120 -> METRIC=135.1328, params=PricingParams(ret_clip_quantile=0.9566437777202054, half_life_days=72, mean_revert_alpha=0.051343176773585505, mean_revert_start=43, fair_up_mult=1.3008261095772935, fair_down_mult=0.8778124682294133, trend_lookback=38, trend_ret_thresh=0.1871082247717301)
# [RS] Trial 72/120 -> METRIC=170.6513, params=PricingParams(ret_clip_quantile=0.9526032607285612, half_life_days=112, mean_revert_alpha=0.09789814731235601, mean_revert_start=46, fair_up_mult=1.3253813140302935, fair_down_mult=0.7847994765314841, trend_lookback=60, trend_ret_thresh=0.23998053721459106)
# [RS] Trial 73/120 -> METRIC=164.0236, params=PricingParams(ret_clip_quantile=0.965461951210158, half_life_days=84, mean_revert_alpha=0.09523767488691205, mean_revert_start=65, fair_up_mult=1.2987430328629468, fair_down_mult=0.7308380985672083, trend_lookback=40, trend_ret_thresh=0.18230195013621897)
# [RS] Trial 74/120 -> METRIC=147.9175, params=PricingParams(ret_clip_quantile=0.9740836766179077, half_life_days=62, mean_revert_alpha=0.044801587471565645, mean_revert_start=58, fair_up_mult=1.5641850250210076, fair_down_mult=0.6915832305859545, trend_lookback=25, trend_ret_thresh=0.1727081381860381)
# [RS] Trial 75/120 -> METRIC=176.9844, params=PricingParams(ret_clip_quantile=0.9540379737755128, half_life_days=115, mean_revert_alpha=0.09963462543040588, mean_revert_start=53, fair_up_mult=1.4232004300559655, fair_down_mult=0.7724842729876988, trend_lookback=50, trend_ret_thresh=0.20199583111642144)
# [RS] Trial 76/120 -> METRIC=112.9872, params=PricingParams(ret_clip_quantile=0.9795839559030142, half_life_days=44, mean_revert_alpha=0.09519919764891564, mean_revert_start=58, fair_up_mult=1.4468639265448136, fair_down_mult=0.8243564723701038, trend_lookback=60, trend_ret_thresh=0.21728697571183525)
# [RS] Trial 77/120 -> METRIC=121.4251, params=PricingParams(ret_clip_quantile=0.9563071329461802, half_life_days=46, mean_revert_alpha=0.02780806458924868, mean_revert_start=64, fair_up_mult=1.4978757166320225, fair_down_mult=0.6726296815947386, trend_lookback=36, trend_ret_thresh=0.22314133251886908)
# [RS] Trial 78/120 -> METRIC=144.9022, params=PricingParams(ret_clip_quantile=0.9664035893274825, half_life_days=67, mean_revert_alpha=0.048252581405661785, mean_revert_start=34, fair_up_mult=1.5591998414495103, fair_down_mult=0.8156183913728877, trend_lookback=42, trend_ret_thresh=0.21271692614002946)
# [RS] Trial 79/120 -> METRIC=183.3270, params=PricingParams(ret_clip_quantile=0.9633146251669613, half_life_days=94, mean_revert_alpha=0.0246125558218879, mean_revert_start=48, fair_up_mult=1.5613005551451875, fair_down_mult=0.7059207286988652, trend_lookback=45, trend_ret_thresh=0.12368206106287134)
# [RS] Trial 80/120 -> METRIC=168.7718, params=PricingParams(ret_clip_quantile=0.9625753095673422, half_life_days=78, mean_revert_alpha=0.037254540901670435, mean_revert_start=25, fair_up_mult=1.4419718667768802, fair_down_mult=0.6599261025003971, trend_lookback=47, trend_ret_thresh=0.22480464522827132)
# [RS] Trial 81/120 -> METRIC=113.0558, params=PricingParams(ret_clip_quantile=0.9685105416073968, half_life_days=45, mean_revert_alpha=0.07889830739581775, mean_revert_start=36, fair_up_mult=1.3588243852585635, fair_down_mult=0.8402577464512948, trend_lookback=42, trend_ret_thresh=0.21629998072011447)
# [RS] Trial 82/120 -> METRIC=189.0037, params=PricingParams(ret_clip_quantile=0.9712449696162168, half_life_days=109, mean_revert_alpha=0.03765848282620241, mean_revert_start=35, fair_up_mult=1.2811363629766939, fair_down_mult=0.6719054132585371, trend_lookback=39, trend_ret_thresh=0.19774386428516963)
# [RS] Trial 83/120 -> METRIC=175.3642, params=PricingParams(ret_clip_quantile=0.9558211939562653, half_life_days=119, mean_revert_alpha=0.07211518942419126, mean_revert_start=37, fair_up_mult=1.3933369618394962, fair_down_mult=0.7940550069000426, trend_lookback=30, trend_ret_thresh=0.19552336790843858)
# [RS] Trial 84/120 -> METRIC=185.3521, params=PricingParams(ret_clip_quantile=0.9567423702539121, half_life_days=100, mean_revert_alpha=0.03865058472772685, mean_revert_start=51, fair_up_mult=1.5289539981186213, fair_down_mult=0.7293017430785063, trend_lookback=39, trend_ret_thresh=0.22936592357815083)
# [RS] Trial 85/120 -> METRIC=132.9316, params=PricingParams(ret_clip_quantile=0.956876012175837, half_life_days=56, mean_revert_alpha=0.02945860807598063, mean_revert_start=40, fair_up_mult=1.514399818880388, fair_down_mult=0.8321002516467644, trend_lookback=51, trend_ret_thresh=0.20049790633178677)
# [RS] Trial 86/120 -> METRIC=155.2850, params=PricingParams(ret_clip_quantile=0.9546470417890637, half_life_days=77, mean_revert_alpha=0.056773434165878364, mean_revert_start=58, fair_up_mult=1.5006545061571206, fair_down_mult=0.8038048816555879, trend_lookback=27, trend_ret_thresh=0.24321511695610432)
# [RS] Trial 87/120 -> METRIC=146.5053, params=PricingParams(ret_clip_quantile=0.9773121906907796, half_life_days=63, mean_revert_alpha=0.03143443582593461, mean_revert_start=46, fair_up_mult=1.4214820042165919, fair_down_mult=0.7750159166382365, trend_lookback=51, trend_ret_thresh=0.16710803304931943)
# [RS] Trial 88/120 -> METRIC=124.2150, params=PricingParams(ret_clip_quantile=0.9642857853547606, half_life_days=50, mean_revert_alpha=0.0710484881348623, mean_revert_start=46, fair_up_mult=1.4397758172235036, fair_down_mult=0.806858336094652, trend_lookback=29, trend_ret_thresh=0.1518752147513648)
# [RS] Trial 89/120 -> METRIC=110.2086, params=PricingParams(ret_clip_quantile=0.9922027914700003, half_life_days=41, mean_revert_alpha=0.050618031977885974, mean_revert_start=65, fair_up_mult=1.3335785555854198, fair_down_mult=0.746813963278158, trend_lookback=29, trend_ret_thresh=0.17624204043307365)
# [RS] Trial 90/120 -> METRIC=195.8910, params=PricingParams(ret_clip_quantile=0.9609635659954539, half_life_days=117, mean_revert_alpha=0.09062888839473812, mean_revert_start=65, fair_up_mult=1.4448270685004005, fair_down_mult=0.6926432105474034, trend_lookback=53, trend_ret_thresh=0.16943984195973777)
# [RS] Trial 91/120 -> METRIC=155.4286, params=PricingParams(ret_clip_quantile=0.9911932420462178, half_life_days=68, mean_revert_alpha=0.04656069003333692, mean_revert_start=27, fair_up_mult=1.4248127207682695, fair_down_mult=0.7044343362877747, trend_lookback=45, trend_ret_thresh=0.1538766063319798)
# [RS] Trial 92/120 -> METRIC=151.4686, params=PricingParams(ret_clip_quantile=0.9667636113248746, half_life_days=111, mean_revert_alpha=0.057929990499534983, mean_revert_start=44, fair_up_mult=1.285874238513451, fair_down_mult=0.8926564143491967, trend_lookback=51, trend_ret_thresh=0.19476616001413205)
# [RS] Trial 93/120 -> METRIC=166.0525, params=PricingParams(ret_clip_quantile=0.9627219173659299, half_life_days=108, mean_revert_alpha=0.0452270949889064, mean_revert_start=27, fair_up_mult=1.4613701089205366, fair_down_mult=0.8599628044042231, trend_lookback=44, trend_ret_thresh=0.23656660701669951)
# [RS] Trial 94/120 -> METRIC=112.5731, params=PricingParams(ret_clip_quantile=0.9939135691608773, half_life_days=42, mean_revert_alpha=0.025314345618864344, mean_revert_start=31, fair_up_mult=1.5687379573539684, fair_down_mult=0.7320663640172571, trend_lookback=55, trend_ret_thresh=0.11188075505980488)
# [RS] Trial 95/120 -> METRIC=192.8282, params=PricingParams(ret_clip_quantile=0.9516969300132663, half_life_days=107, mean_revert_alpha=0.024881078790247323, mean_revert_start=54, fair_up_mult=1.4622397414426889, fair_down_mult=0.7125108120164256, trend_lookback=47, trend_ret_thresh=0.1355264483859957)
# [RS] Trial 96/120 -> METRIC=121.8374, params=PricingParams(ret_clip_quantile=0.9575274112418412, half_life_days=48, mean_revert_alpha=0.09934101351105959, mean_revert_start=53, fair_up_mult=1.5258423471094382, fair_down_mult=0.7905880762615363, trend_lookback=48, trend_ret_thresh=0.23420593059147138)
# [RS] Trial 97/120 -> METRIC=175.4071, params=PricingParams(ret_clip_quantile=0.9765926485147328, half_life_days=90, mean_revert_alpha=0.07602552245914748, mean_revert_start=58, fair_up_mult=1.2913035995842863, fair_down_mult=0.6625133053982111, trend_lookback=40, trend_ret_thresh=0.17270098005130233)
# [RS] Trial 98/120 -> METRIC=188.4392, params=PricingParams(ret_clip_quantile=0.9650942316976413, half_life_days=114, mean_revert_alpha=0.07492956970353484, mean_revert_start=38, fair_up_mult=1.3851697330875612, fair_down_mult=0.7203897414110966, trend_lookback=43, trend_ret_thresh=0.1636014222781033)
# [RS] Trial 99/120 -> METRIC=175.7322, params=PricingParams(ret_clip_quantile=0.9723783558598991, half_life_days=119, mean_revert_alpha=0.04437796799790968, mean_revert_start=38, fair_up_mult=1.5254844879610348, fair_down_mult=0.8463898713444212, trend_lookback=28, trend_ret_thresh=0.15159474375387771)
# [RS] Trial 100/120 -> METRIC=153.7214, params=PricingParams(ret_clip_quantile=0.9946521807987019, half_life_days=66, mean_revert_alpha=0.08408269867971677, mean_revert_start=43, fair_up_mult=1.497915342674375, fair_down_mult=0.6973745828380459, trend_lookback=53, trend_ret_thresh=0.1582322342541515)
# [RS] Trial 101/120 -> METRIC=160.3818, params=PricingParams(ret_clip_quantile=0.9707473873973573, half_life_days=73, mean_revert_alpha=0.023320353356133243, mean_revert_start=34, fair_up_mult=1.2931136359648119, fair_down_mult=0.7076929827757917, trend_lookback=29, trend_ret_thresh=0.24542231808083492)
# [RS] Trial 102/120 -> METRIC=134.2023, params=PricingParams(ret_clip_quantile=0.9534030717994921, half_life_days=83, mean_revert_alpha=0.09981378920176205, mean_revert_start=48, fair_up_mult=1.3725544215016767, fair_down_mult=0.8772780789226946, trend_lookback=53, trend_ret_thresh=0.24301624399765392)
# [RS] Trial 103/120 -> METRIC=145.7415, params=PricingParams(ret_clip_quantile=0.9821947477694185, half_life_days=73, mean_revert_alpha=0.025911990820762308, mean_revert_start=41, fair_up_mult=1.5265605907461972, fair_down_mult=0.8918011793625195, trend_lookback=26, trend_ret_thresh=0.1802931710512039)
# [RS] Trial 104/120 -> METRIC=174.4276, params=PricingParams(ret_clip_quantile=0.9846271168615549, half_life_days=83, mean_revert_alpha=0.024881985660579958, mean_revert_start=27, fair_up_mult=1.42759508164961, fair_down_mult=0.6672037976079129, trend_lookback=48, trend_ret_thresh=0.10534436072235792)
# [RS] Trial 105/120 -> METRIC=164.5205, params=PricingParams(ret_clip_quantile=0.9919925691903672, half_life_days=90, mean_revert_alpha=0.08181907652341099, mean_revert_start=28, fair_up_mult=1.4347951817712064, fair_down_mult=0.7822279962704266, trend_lookback=34, trend_ret_thresh=0.12333489176878772)
# [RS] Trial 106/120 -> METRIC=106.5231, params=PricingParams(ret_clip_quantile=0.9666050519509314, half_life_days=41, mean_revert_alpha=0.06370043603749463, mean_revert_start=28, fair_up_mult=1.4583280453345258, fair_down_mult=0.8462786873053278, trend_lookback=57, trend_ret_thresh=0.23490859000899916)
# [RS] Trial 107/120 -> METRIC=165.3610, params=PricingParams(ret_clip_quantile=0.9595848281618503, half_life_days=85, mean_revert_alpha=0.06488609247292117, mean_revert_start=36, fair_up_mult=1.5698298343384833, fair_down_mult=0.7749737569146274, trend_lookback=32, trend_ret_thresh=0.19028907792666494)
# [RS] Trial 108/120 -> METRIC=191.9802, params=PricingParams(ret_clip_quantile=0.9667821644254281, half_life_days=108, mean_revert_alpha=0.07094589332721078, mean_revert_start=61, fair_up_mult=1.5772137825123256, fair_down_mult=0.68940702841218, trend_lookback=33, trend_ret_thresh=0.16928864409355057)
# [RS] Trial 109/120 -> METRIC=164.6814, params=PricingParams(ret_clip_quantile=0.9718086029157351, half_life_days=107, mean_revert_alpha=0.06281297041377858, mean_revert_start=50, fair_up_mult=1.26934612860933, fair_down_mult=0.8423369002306595, trend_lookback=35, trend_ret_thresh=0.09808186819637256)
# [RS] Trial 110/120 -> METRIC=159.1529, params=PricingParams(ret_clip_quantile=0.9594633062855057, half_life_days=71, mean_revert_alpha=0.025552256233516753, mean_revert_start=62, fair_up_mult=1.2592525922828504, fair_down_mult=0.657429501710628, trend_lookback=40, trend_ret_thresh=0.12941671928560144)
# [RS] Trial 111/120 -> METRIC=170.4052, params=PricingParams(ret_clip_quantile=0.959434416787307, half_life_days=106, mean_revert_alpha=0.03025272266288434, mean_revert_start=49, fair_up_mult=1.336487497725139, fair_down_mult=0.8525471444070484, trend_lookback=28, trend_ret_thresh=0.236754883689412)
# [RS] Trial 112/120 -> METRIC=131.3673, params=PricingParams(ret_clip_quantile=0.9597698361323526, half_life_days=57, mean_revert_alpha=0.061079757579385996, mean_revert_start=61, fair_up_mult=1.45447517802038, fair_down_mult=0.8281893635641069, trend_lookback=31, trend_ret_thresh=0.08045907228095295)
# [RS] Trial 113/120 -> METRIC=157.6989, params=PricingParams(ret_clip_quantile=0.9677144026510703, half_life_days=87, mean_revert_alpha=0.05500946813600599, mean_revert_start=46, fair_up_mult=1.4145530846687666, fair_down_mult=0.8320525864371083, trend_lookback=55, trend_ret_thresh=0.12775915592678372)
# [RS] Trial 114/120 -> METRIC=140.4908, params=PricingParams(ret_clip_quantile=0.9555005691151687, half_life_days=57, mean_revert_alpha=0.032472670499997025, mean_revert_start=30, fair_up_mult=1.5967507072649636, fair_down_mult=0.6601567756242794, trend_lookback=27, trend_ret_thresh=0.21964868732264398)
# [RS] Trial 115/120 -> METRIC=139.0205, params=PricingParams(ret_clip_quantile=0.9628150175754835, half_life_days=62, mean_revert_alpha=0.07653927598325891, mean_revert_start=44, fair_up_mult=1.2602888648202517, fair_down_mult=0.7845925111930234, trend_lookback=40, trend_ret_thresh=0.18225329278169328)
# [RS] Trial 116/120 -> METRIC=152.7232, params=PricingParams(ret_clip_quantile=0.9729961622077231, half_life_days=80, mean_revert_alpha=0.06655317767814004, mean_revert_start=48, fair_up_mult=1.5554524067916289, fair_down_mult=0.8234983161324375, trend_lookback=56, trend_ret_thresh=0.12030384909840575)
# [RS] Trial 117/120 -> METRIC=167.9813, params=PricingParams(ret_clip_quantile=0.9574785562401696, half_life_days=89, mean_revert_alpha=0.027141760967141177, mean_revert_start=30, fair_up_mult=1.3908185735524168, fair_down_mult=0.8245834432850889, trend_lookback=44, trend_ret_thresh=0.12966198831916065)
# [RS] Trial 118/120 -> METRIC=157.0023, params=PricingParams(ret_clip_quantile=0.9563383655626512, half_life_days=92, mean_revert_alpha=0.07215466855431948, mean_revert_start=55, fair_up_mult=1.5855661420973155, fair_down_mult=0.8389476586619897, trend_lookback=52, trend_ret_thresh=0.22736646307035646)
# [RS] Trial 119/120 -> METRIC=167.4507, params=PricingParams(ret_clip_quantile=0.9773554288040555, half_life_days=84, mean_revert_alpha=0.08496402091164978, mean_revert_start=33, fair_up_mult=1.5491418949225604, fair_down_mult=0.7453511649476882, trend_lookback=31, trend_ret_thresh=0.24034788272191765)
# [RS] Trial 120/120 -> METRIC=154.5819, params=PricingParams(ret_clip_quantile=0.9828093275863204, half_life_days=74, mean_revert_alpha=0.07470217621855821, mean_revert_start=47, fair_up_mult=1.3313850502548017, fair_down_mult=0.7665469899362278, trend_lookback=52, trend_ret_thresh=0.17551934383430312)
#
# === BEST PRICING PARAMS v5.2 Option 2 (Hybrid + Regime, Pure FPT) ===
# PricingParams(ret_clip_quantile=0.9666050519509314, half_life_days=41, mean_revert_alpha=0.06370043603749463, mean_revert_start=28, fair_up_mult=1.4583280453345258, fair_down_mult=0.8462786873053278, trend_lookback=57, trend_ret_thresh=0.23490859000899916)
# CV METRIC (0.5*MSE_50 + 0.5*MSE_100): 106.52307298210218
# Modeling DF shape: (1128, 60)
# === XGB RESIDUAL MODEL (1128 samples) ===
# Train (resid) -> MSE: 4.333776e-05 | MAE: 4.889853e-03
# Val (resid) -> MSE: 5.014206e-04 | MAE: 1.726129e-02
# Test (resid) -> MSE: 3.111402e-04 | MAE: 1.286696e-02
# [RESID] std=1.063816e-02, mean=1.727653e-03
# Saved FPT_forecast.csv ✅
# Saved submission.csv ✅
